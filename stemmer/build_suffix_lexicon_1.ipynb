# %%
from stemmer import *

# %%
# Let the stemmer take as input the output of the tokenizer (a list of tokens)
file_path = "/Users/lkk/Documents/BOUN CMPE/CMPE 561-Natural Language Processing/Application Project 1/corpora/UD_Turkish-BOUN/tr_boun-ud-test.txt"

main(file_path, InputType.FILE_PATH)
# Out:
# Surface:Çünkü, Stem:Çün
# Surface:ben, Stem:be
# Surface:de, Stem:de
# Surface:o, Stem:o
# Surface:yaşadığı, Stem:yaşa
# Surface:çevreyi, Stem:çevre
# Surface:kirleterek, Stem:kirle
# Surface:bozulmasına, Stem:boz
# Surface:neden, Stem:ne
# Surface:olan, Stem:o
# Surface:tüm, Stem:tü
# Surface:uyarılara, Stem:uyarı
# Surface:kulağını, Stem:kula
# Surface:tıkayan, Stem:tıka
# Surface:soya, Stem:so
# Surface:aitim, Stem:ai
# Surface:Kimileri, Stem:Kim
# Surface:buna, Stem:bu
# Surface:kader, Stem:ka
# Surface:diyordu, Stem:di
# Surface:kimileri, Stem:kim
# Surface:unut, Stem:unu
# Surface:Bu, Stem:Bu
# Surface:da, Stem:da
# Surface:zaman, Stem:za
# Surface:ister, Stem:ist
# Surface:emek, Stem:eme
# Surface:ister, Stem:ist
# Surface:İki, Stem:İk
# Surface:veli, Stem:ve
# Surface:dokunulsa, Stem:dokunul
# Surface:ağlayacaktı, Stem:ağlay
# Surface:Bu, Stem:Bu
# Surface:meslek, Stem:mesle
# Surface:böyledir, Stem:bö
# Surface:Filmde, Stem:Fil
# Surface:kamburunu, Stem:kambur
# Surface:çıkarmış, Stem:çık
# Surface:eski, Stem:es
# Surface:Yugoslav, Stem:Yugoslav
# Surface:lideri, Stem:lide
# Surface:iki, Stem:ik
# Surface:kişinin, Stem:kiş
# Surface:arasında, Stem:ara
# Surface:elleri, Stem:el
# Surface:önden, Stem:ön
# Surface:bağlı, Stem:bağ
# Surface:cezaevi, Stem:cezaev
# Surface:avlusunda, Stem:avlu
# Surface:yürüyor, Stem:yür
# Surface:Sabahları, Stem:Sabah
# Surface:hiçbir, Stem:hiç
# Surface:şey, Stem:şe
# Surface:yemeden, Stem:ye
# Surface:içmeden, Stem:iç
# Surface:paldür, Stem:pal
# Surface:küldür, Stem:kül
# Surface:çıkıyorum, Stem:çık
# Surface:evden, Stem:ev
# Surface:Bu, Stem:Bu
# Surface:albüm, Stem:alb
# Surface:hit, Stem:hi
# Surface:şarkı, Stem:şar
# Surface:çıkarmaz, Stem:çık
# Surface:dedim, Stem:de
# Surface:Bu, Stem:Bu
# Surface:tesisin, Stem:tesi
# Surface:büyümesinde, Stem:büyü
# Surface:büyük, Stem:büyü
# Surface:katkısı, Stem:katkı
# Surface:oldu, Stem:ol
# Surface:Çağırdım, Stem:Çağı
# Surface:Genelkurmay, Stem:Genelkurm
# Surface:Ama, Stem:Am
# Surface:önce, Stem:ön
# Surface:uyumadan, Stem:uyu
# Surface:önce, Stem:ön
# Surface:notlarıma, Stem:not
# Surface:bir, Stem:bi
# Surface:çeki, Stem:çe
# Surface:düzen, Stem:düz
# Surface:vermem, Stem:ver
# Surface:gerek, Stem:gere
# Surface:Saçlarını, Stem:Saç
# Surface:yıkamış, Stem:yıka
# Surface:Hayır, Stem:Hay
# Surface:ben, Stem:be
# Surface:masal, Stem:ma
# Surface:istiyorum, Stem:is
# Surface:Helikopterler, Stem:Helikopt
# Surface:ve, Stem:ve
# Surface:uçaklar, Stem:uç
# Surface:da, Stem:da
# Surface:gökyüzünde, Stem:gökyüz
# Surface:uçarlar, Stem:uç
# Surface:Postmodernleşen, Stem:Postmodern
# Surface:dünyayla, Stem:dünya
# Surface:birlikte, Stem:bir
# Surface:edebiyatın, Stem:edebiya
# Surface:algılanışı, Stem:algı
# Surface:da, Stem:da
# Surface:dönüştü, Stem:dön
# Surface:giderek, Stem:gi
# Surface:bir, Stem:bi
# Surface:eğlence, Stem:eğlen
# Surface:nesnesi, Stem:nesne
# Surface:hoşça, Stem:hoş
# Surface:vakit, Stem:vaki
# Surface:geçirme, Stem:geç
# Surface:aracı, Stem:ara
# Surface:olarak, Stem:o
# Surface:değerlendiriliyor, Stem:değer
# Surface:Sonradan, Stem:Sonr
# Surface:bir, Stem:bi
# Surface:inceldi, Stem:incel
# Surface:bir, Stem:bi
# Surface:inceldi, Stem:incel
# Surface:Baba, Stem:Ba
# Surface:deriz, Stem:de
# Surface:baba, Stem:ba
# Surface:ölüm, Stem:öl
# Surface:nedir, Stem:ne
# Surface:şöyleydi, Stem:şöyle
# Surface:Bu, Stem:Bu
# Surface:soruya, Stem:soru
# Surface:Tabi, Stem:Ta
# Surface:olur, Stem:ol
# Surface:diyerek, Stem:di
# Surface:uzun, Stem:uz
# Surface:uzun, Stem:uz
# Surface:anlatmaya, Stem:anla
# Surface:girişeceğini, Stem:giriş
# Surface:zannediyordum, Stem:zanned
# Surface:İstanbulspor, Stem:İstanbulspo
# Surface:Vanspor, Stem:Vanspo
# Surface:Karşıyaka, Stem:Karşıyak
# Surface:Göztepe, Stem:Göztep
# Surface:gibi, Stem:gi
# Surface:bazı, Stem:ba
# Surface:kulüpler, Stem:kulüp
# Surface:dernek, Stem:derne
# Surface:yapısı, Stem:yapı
# Surface:dışında, Stem:dış
# Surface:futbol, Stem:futbo
# Surface:şubelerini, Stem:şube
# Surface:kurulan, Stem:kur
# Surface:veya, Stem:ve
# Surface:kurulmuş, Stem:kur
# Surface:bulunan, Stem:bul
# Surface:anonim, Stem:anon
# Surface:şirketlere, Stem:şirket
# Surface:devrediyor, Stem:devre
# Surface:Birtakım, Stem:Birtak
# Surface:gerilimler, Stem:gerilim
# Surface:yaşadık, Stem:yaşa
# Surface:Hatta, Stem:Hat
# Surface:yılında, Stem:yı
# Surface:geri, Stem:ge
# Surface:döndükten, Stem:dön
# Surface:sonra, Stem:son
# Surface:bile, Stem:bi
# Surface:Meclis, Stem:Mecli
# Surface:kararı, Stem:kar
# Surface:gereği, Stem:gere
# Surface:Doğu, Stem:Do
# Surface:güvenliğini, Stem:güven
# Surface:sağlamak, Stem:sağla
# Surface:üzere, Stem:üze
# Surface:deniz, Stem:de
# Surface:unsurunu, Stem:unsur
# Surface:oluşturan, Stem:oluş
# Surface:Gaziantep, Stem:Gaziantep
# Surface:Firkateyni, Stem:Firkatey
# Surface:ve, Stem:ve
# Surface:iki, Stem:ik
# Surface:korvetle, Stem:korvet
# Surface:yaklaşık, Stem:yakl
# Surface:denizci, Stem:deniz
# Surface:bir, Stem:bi
# Surface:hafta, Stem:haf
# Surface:içinde, Stem:iç
# Surface:Doğu, Stem:Do
# Surface:gidecek, Stem:gi
# Surface:Geçim, Stem:Geç
# Surface:kaygısı, Stem:kaygı
# Surface:içinde, Stem:iç
# Surface:olanlar, Stem:ol
# Surface:güçlü, Stem:güç
# Surface:olmasını, Stem:ol
# Surface:istiyor, Stem:is
# Surface:Herkes, Stem:Herke
# Surface:öyle, Stem:öy
# Surface:ya, Stem:ya
# Surface:da, Stem:da
# Surface:böyle, Stem:bö
# Surface:içinde, Stem:iç
# Surface:bir, Stem:bi
# Surface:şekilde, Stem:şekil
# Surface:bir, Stem:bi
# Surface:şeylere, Stem:şey
# Surface:dair, Stem:da
# Surface:mutlaka, Stem:mutlak
# Surface:bir, Stem:bi
# Surface:umut, Stem:umu
# Surface:taşır, Stem:taş
# Surface:Duş, Stem:Duş
# Surface:veya, Stem:ve
# Surface:banyo, Stem:bany
# Surface:esnasında, Stem:esna
# Surface:su, Stem:su
# Surface:kullanarak, Stem:kul
# Surface:elle, Stem:el
# Surface:ya, Stem:ya
# Surface:da, Stem:da
# Surface:yine, Stem:yi
# Surface:su, Stem:su
# Surface:kullanarak, Stem:kul
# Surface:her, Stem:he
# Surface:hangi, Stem:han
# Surface:bir, Stem:bi
# Surface:parfümsüz, Stem:parfüm
# Surface:beyaz, Stem:bey
# Surface:sabunla, Stem:sab
# Surface:yapılacak, Stem:yap
# Surface:olan, Stem:o
# Surface:temizlik, Stem:temiz
# Surface:vajinanın, Stem:vajin
# Surface:ön, Stem:ön
# Surface:bölgesinden, Stem:bölge
# Surface:klitoris, Stem:klitori
# Surface:başlangıcından, Stem:başlangı
# Surface:anüse, Stem:anü
# Surface:dışkılık, Stem:dışk
# Surface:doğru, Stem:doğr
# Surface:olmalıdır, Stem:ol
# Surface:Oluşan, Stem:Oluş
# Surface:kabarcıklar, Stem:kabarcık
# Surface:patlatılmaz, Stem:patlat
# Surface:Ben, Stem:Be
# Surface:kendi, Stem:ke
# Surface:hesabıma, Stem:hesab
# Surface:bir, Stem:bi
# Surface:denizin, Stem:de
# Surface:kenarında, Stem:ken
# Surface:elimde, Stem:el
# Surface:bir, Stem:bi
# Surface:rakı, Stem:ra
# Surface:bardağı, Stem:barda
# Surface:ve, Stem:ve
# Surface:yanımda, Stem:yan
# Surface:Isabelle, Stem:Isabel
# Surface:Adjani, Stem:Adj
# Surface:ile, Stem:il
# Surface:oturduğumda, Stem:otur
# Surface:mutlu, Stem:mut
# Surface:oluyorum, Stem:ol
# Surface:Parasız, Stem:Para
# Surface:pulsuzduk, Stem:pulsuz
# Surface:Behlül, Stem:Behlü
# Surface:teyzemin, Stem:teyze
# Surface:ellerine, Stem:el
# Surface:bakıyorduk, Stem:bak
# Surface:Kimileri, Stem:Kim
# Surface:hemen, Stem:he
# Surface:çizmeye, Stem:çiz
# Surface:başladı, Stem:baş
# Surface:Ahmet, Stem:Ahme
# Surface:Hamdi, Stem:Ham
# Surface:Tanpınar, Stem:Tanpın
# Surface:Beş, Stem:Beş
# Surface:Şehir, Stem:Şeh
# Surface:adlı, Stem:ad
# Surface:başyapıtında, Stem:başyapı
# Surface:dile, Stem:di
# Surface:getirirken, Stem:getir
# Surface:yılının, Stem:yı
# Surface:o, Stem:o
# Surface:müthiş, Stem:müth
# Surface:günlerinden, Stem:gün
# Surface:de, Stem:de
# Surface:söz, Stem:söz
# Surface:açar, Stem:aç
# Surface:önce, Stem:ön
# Surface:şu, Stem:şu
# Surface:otelden, Stem:otel
# Surface:içeri, Stem:içe
# Surface:zor, Stem:zo
# Surface:girebilirdik, Stem:girebil
# Surface:Nazik, Stem:Naz
# Surface:ve, Stem:ve
# Surface:sıcak, Stem:sıc
# Surface:bir, Stem:bi
# Surface:özür, Stem:öz
# Surface:gülümseyişiyle, Stem:gülümse
# Surface:Umutluydum, Stem:Umutluy
# Surface:Kızı, Stem:Kı
# Surface:al, Stem:al
# Surface:eve, Stem:ev
# Surface:götür, Stem:gö
# Surface:dinlensin, Stem:dinlen
# Surface:Çocuğun, Stem:Çocu
# Surface:ödü, Stem:öd
# Surface:patladı, Stem:pat
# Surface:Şair, Stem:Şa
# Surface:sizin, Stem:siz
# Surface:yaşadığınız, Stem:yaşa
# Surface:ilden, Stem:il
# Surface:de, Stem:de
# Surface:söz, Stem:söz
# Surface:edecek, Stem:ed
# Surface:olsaydı, Stem:ol
# Surface:sizce, Stem:siz
# Surface:hangi, Stem:han
# Surface:özelliğini, Stem:özel
# Surface:söylerdi, Stem:söy
# Surface:Ben, Stem:Be
# Surface:yol, Stem:yo
# Surface:bilmem, Stem:bil
# Surface:iz, Stem:iz
# Surface:bilmem, Stem:bil
# Surface:Ama, Stem:Am
# Surface:rahatsız, Stem:rahat
# Surface:değilim, Stem:değ
# Surface:Öğretmenlere, Stem:Öğretm
# Surface:mutlaka, Stem:mutlak
# Surface:teşekkür, Stem:teşekk
# Surface:edin, Stem:ed
# Surface:İşin, Stem:İş
# Surface:en, Stem:en
# Surface:ilginç, Stem:ilginç
# Surface:tarafı, Stem:tara
# Surface:ise, Stem:is
# Surface:öğretmenlerimizin, Stem:öğretmen
# Surface:bize, Stem:biz
# Surface:hemen, Stem:he
# Surface:her, Stem:he
# Surface:zaman, Stem:za
# Surface:söyledikleri, Stem:söyle
# Surface:bir, Stem:bi
# Surface:şeyi, Stem:şe
# Surface:kendilerinin, Stem:kendi
# Surface:uygulamamasıydı, Stem:uygula
# Surface:Bu, Stem:Bu
# Surface:uygulamayı, Stem:uygula
# Surface:kurallaştırmamıştır, Stem:kurallaştır
# Surface:Televizyonların, Stem:Televizyo
# Surface:yaptığı, Stem:yap
# Surface:tahminler, Stem:tahmin
# Surface:hayır, Stem:hay
# Surface:tarafının, Stem:tara
# Surface:çok, Stem:ço
# Surface:az, Stem:az
# Surface:farkla, Stem:fark
# Surface:önde, Stem:ön
# Surface:gittiğini, Stem:gi
# Surface:gösteriyor, Stem:göster
# Surface:Bizi, Stem:Bi
# Surface:korkuturlardı, Stem:korkut
# Surface:şimdi, Stem:şim
# Surface:kuyu, Stem:ku
# Surface:anası, Stem:an
# Surface:çıkacak, Stem:çık
# Surface:diye, Stem:di
# Surface:Örgütün, Stem:Örgü
# Surface:gizli, Stem:giz
# Surface:araştırmasında, Stem:araştır
# Surface:sirk, Stem:sir
# Surface:görevlileriyle, Stem:görevli
# Surface:birlikte, Stem:bir
# Surface:çalışıldığı, Stem:çalış
# Surface:ve, Stem:ve
# Surface:kötü, Stem:kö
# Surface:muamelelerin, Stem:muamele
# Surface:filme, Stem:fil
# Surface:alındığı, Stem:al
# Surface:belirtildi, Stem:belir
# Surface:Oluktan, Stem:Oluk
# Surface:düşenleri, Stem:düş
# Surface:Kitap, Stem:Kit
# Surface:okumak, Stem:oku
# Surface:neden, Stem:ne
# Surface:önemlidir, Stem:önem
# Surface:Aslan, Stem:As
# Surface:burcu, Stem:bur
# Surface:kadınları, Stem:kadı
# Surface:yalandan, Stem:yal
# Surface:dolandan, Stem:dol
# Surface:nefret, Stem:nefre
# Surface:ederler, Stem:ed
# Surface:Değerlendirme, Stem:Değer
# Surface:Soruları, Stem:Soru
# Surface:Hayır, Stem:Hay
# Surface:demiş, Stem:de
# Surface:çocuk, Stem:çoc
# Surface:Başka, Stem:Başk
# Surface:bir, Stem:bi
# Surface:tencerede, Stem:tencere
# Surface:yağ, Stem:yağ
# Surface:bir, Stem:bi
# Surface:çorba, Stem:çor
# Surface:kaşığı, Stem:kaşı
# Surface:un, Stem:un
# Surface:ile, Stem:il
# Surface:pembeleştirilir, Stem:pembeleş
# Surface:Bebe, Stem:Be
# Surface:gibi, Stem:gi
# Surface:kollarımda, Stem:kol
# Surface:yaylattım, Stem:yayla
# Surface:Yeni, Stem:Ye
# Surface:kıtalara, Stem:kıta
# Surface:açılmış, Stem:aç
# Surface:kâşifler, Stem:kâşif
# Surface:Böyle, Stem:Bö
# Surface:kadrolarla, Stem:kadro
# Surface:ekonomide, Stem:ekonomi
# Surface:eğitimde, Stem:eğit
# Surface:her, Stem:he
# Surface:alanda, Stem:al
# Surface:bilimsel, Stem:bilim
# Surface:rasyonel, Stem:rasyone
# Surface:politikalar, Stem:politika
# Surface:üretilemediği, Stem:üret
# Surface:gibi, Stem:gi
# Surface:ele, Stem:el
# Surface:geçen, Stem:geç
# Surface:iç, Stem:iç
# Surface:ve, Stem:ve
# Surface:dış, Stem:dış
# Surface:kaynaklar, Stem:kayn
# Surface:yardımlar, Stem:yardım
# Surface:da, Stem:da
# Surface:yeterince, Stem:yeter
# Surface:değerlendirilemiyor, Stem:değerlendir
# Surface:hatta, Stem:hat
# Surface:israf, Stem:israf
# Surface:olunuyor, Stem:ol
# Surface:Bu, Stem:Bu
# Surface:sorunun, Stem:sor
# Surface:yanıtı, Stem:yanı
# Surface:kesin, Stem:ke
# Surface:olarak, Stem:o
# Surface:hayır, Stem:hay
# Surface:dır, Stem:dı
# Surface:KAÇ, Stem:KAÇ
# Surface:KİŞİLİK, Stem:KİŞİLİK
# Surface:Öyle, Stem:Öy
# Surface:güzel, Stem:güze
# Surface:yetiştirmişsiniz, Stem:yetiştir
# Surface:ki, Stem:ki
# Surface:onu, Stem:o
# Surface:Stadın, Stem:Sta
# Surface:ışıkları, Stem:ışık
# Surface:söndü, Stem:sön
# Surface:Hem, Stem:He
# Surface:tutuklu, Stem:tutuk
# Surface:olup, Stem:ol
# Surface:hem, Stem:he
# Surface:bir, Stem:bi
# Surface:şey, Stem:şe
# Surface:yapamazsınız, Stem:yap
# Surface:Toplumun, Stem:Toplu
# Surface:bu, Stem:bu
# Surface:kadar, Stem:kad
# Surface:açlık, Stem:aç
# Surface:işsizlik, Stem:iş
# Surface:eşitsizlik, Stem:eşit
# Surface:gibi, Stem:gi
# Surface:sorunu, Stem:sor
# Surface:varken, Stem:va
# Surface:karnı, Stem:kar
# Surface:lafa, Stem:laf
# Surface:tok, Stem:to
# Surface:Ağır, Stem:Ağ
# Surface:ama, Stem:am
# Surface:emin, Stem:em
# Surface:adımlarla, Stem:adım
# Surface:ilerleyin, Stem:ilerle
# Surface:Daha, Stem:Dah
# Surface:nasıl, Stem:nas
# Surface:çanta, Stem:çan
# Surface:derdinde, Stem:der
# Surface:olmayayım, Stem:olma
# Surface:Öyle, Stem:Öy
# Surface:parçalar, Stem:parça
# Surface:var, Stem:va
# Surface:işte, Stem:iş
# Surface:Ama, Stem:Am
# Surface:gözlerinin, Stem:göz
# Surface:ıslandığını, Stem:ıs
# Surface:gördüm, Stem:gör
# Surface:Süzme, Stem:Süz
# Surface:yoğurt, Stem:yoğur
# Surface:çırpılmış, Stem:çırp
# Surface:yumurta, Stem:yumur
# Surface:ve, Stem:ve
# Surface:çorba, Stem:çor
# Surface:kaşığı, Stem:kaşı
# Surface:un, Stem:un
# Surface:karışımını, Stem:karışı
# Surface:azar, Stem:az
# Surface:azar, Stem:az
# Surface:ilave, Stem:ilav
# Surface:ederek, Stem:ed
# Surface:karıştırın, Stem:karış
# Surface:Derken, Stem:De
# Surface:Wonka, Stem:Wonk
# Surface:çikolatalarına, Stem:çikolata
# Surface:gizlenmiş, Stem:giz
# Surface:altın, Stem:al
# Surface:bileti, Stem:bile
# Surface:bulan, Stem:bu
# Surface:şanslı, Stem:şans
# Surface:çocuğu, Stem:çocu
# Surface:bütün, Stem:bü
# Surface:sırlarını, Stem:sır
# Surface:ve, Stem:ve
# Surface:büyüsünü, Stem:büyü
# Surface:göstereceği, Stem:göster
# Surface:fabrikasına, Stem:fabrika
# Surface:davet, Stem:dave
# Surface:edip, Stem:ed
# Surface:gezdireceğini, Stem:gezdir
# Surface:ve, Stem:ve
# Surface:içlerinden, Stem:iç
# Surface:birine, Stem:bi
# Surface:fabrikayı, Stem:fabrika
# Surface:devredeceği, Stem:devre
# Surface:sürprizini, Stem:sürpriz
# Surface:ilan, Stem:il
# Surface:edince, Stem:ed
# Surface:bir, Stem:bi
# Surface:bilet, Stem:bile
# Surface:avıdır, Stem:av
# Surface:başlıyor, Stem:başl
# Surface:KELAYNAK, Stem:KELAYNAK
# Surface:KUŞU, Stem:KUŞU
# Surface:Ülkemi, Stem:Ülke
# Surface:aydınlatan, Stem:aydınla
# Surface:medeniyet, Stem:medeniye
# Surface:hürriyet, Stem:hürriye
# Surface:Gerçek, Stem:Gerçe
# Surface:bir, Stem:bi
# Surface:koleksiyoncu, Stem:koleksiyon
# Surface:kazanç, Stem:kazanç
# Surface:amacı, Stem:ama
# Surface:gütmez, Stem:gü
# Surface:sırf, Stem:sırf
# Surface:zevki, Stem:zev
# Surface:için, Stem:iç
# Surface:koleksiyon, Stem:koleksiyo
# Surface:yapar, Stem:yap
# Surface:Bu, Stem:Bu
# Surface:eylem, Stem:eyle
# Surface:kent, Stem:ken
# Surface:insanının, Stem:ins
# Surface:kültürel, Stem:kültüre
# Surface:gelişiminin, Stem:gelişi
# Surface:doruklarına, Stem:doruk
# Surface:varmasının, Stem:var
# Surface:bir, Stem:bi
# Surface:göstergesi, Stem:gösterge
# Surface:kabul, Stem:kabu
# Surface:edilir, Stem:ed
# Surface:Bizim, Stem:Biz
# Surface:gündelik, Stem:günd
# Surface:gerçekliğe, Stem:gerçek
# Surface:bakışımızın, Stem:bakış
# Surface:içerdiği, Stem:içer
# Surface:ideolojik, Stem:ideolo
# Surface:etik, Stem:et
# Surface:ve, Stem:ve
# Surface:estetik, Stem:este
# Surface:değerlerin, Stem:değer
# Surface:toplamıdır, Stem:topla
# Surface:Psikolojik, Stem:Psikolo
# Surface:psikiyatrik, Stem:psikiyatr
# Surface:organik, Stem:organ
# Surface:ilaç, Stem:ilaç
# Surface:kullanımı, Stem:kulla
# Surface:gibi, Stem:gi
# Surface:nedenlerle, Stem:ned
# Surface:ortaya, Stem:orta
# Surface:çıkar, Stem:çık
# Surface:Hücum, Stem:Hüc
# Surface:etmesini, Stem:et
# Surface:bilen, Stem:bi
# Surface:kadar, Stem:kad
# Surface:bilmeyen, Stem:bil
# Surface:de, Stem:de
# Surface:vardı, Stem:va
# Surface:bu, Stem:bu
# Surface:ülkede, Stem:ülke
# Surface:son, Stem:so
# Surface:vuruşu, Stem:vur
# Surface:yapan, Stem:yap
# Surface:kadar, Stem:kad
# Surface:yapamayan, Stem:yap
# Surface:da, Stem:da
# Surface:orta, Stem:or
# Surface:sahada, Stem:saha
# Surface:top, Stem:top
# Surface:çeviren, Stem:çev
# Surface:de, Stem:de
# Surface:çevirmeyen, Stem:çevir
# Surface:de, Stem:de
# Surface:Evimde, Stem:Ev
# Surface:olmak, Stem:ol
# Surface:istiyorum, Stem:is
# Surface:Doktor, Stem:Dokto
# Surface:Alooo, Stem:Aloo
# Surface:der, Stem:de
# Surface:demez, Stem:de
# Surface:ölü, Stem:öl
# Surface:Alo, Stem:Al
# Surface:buyrunuz, Stem:buyr
# Surface:diye, Stem:di
# Surface:dikelmiş, Stem:dikel
# Surface:Şimdi, Stem:Şim
# Surface:yaşadığım, Stem:yaşa
# Surface:batının, Stem:ba
# Surface:verimli, Stem:verim
# Surface:bölgelerinden, Stem:bölge
# Surface:doğduğum, Stem:doğ
# Surface:yörelere, Stem:yöre
# Surface:her, Stem:he
# Surface:gidişimde, Stem:gidiş
# Surface:bizim, Stem:biz
# Surface:kupkuru, Stem:kupkur
# Surface:dağlarımıza, Stem:dağ
# Surface:bozkırlarımıza, Stem:bozkır
# Surface:yaklaştıkça, Stem:yak
# Surface:burnumun, Stem:burnu
# Surface:direği, Stem:dire
# Surface:sızlıyor, Stem:sızl
# Surface:Şimdi, Stem:Şim
# Surface:P, Stem:P
# Surface:ye, Stem:ye
# Surface:basmanın, Stem:bas
# Surface:tam, Stem:ta
# Surface:zamanı, Stem:za
# Surface:işte, Stem:iş
# Surface:Domates, Stem:Domate
# Surface:ve, Stem:ve
# Surface:domates, Stem:domate
# Surface:salçası, Stem:salç
# Surface:ilave, Stem:ilav
# Surface:edip, Stem:ed
# Surface:soteleyin, Stem:sotele
# Surface:Babasının, Stem:Baba
# Surface:el, Stem:el
# Surface:yazısıyla, Stem:yazı
# Surface:yazılmış, Stem:yaz
# Surface:küçük, Stem:küçü
# Surface:bir, Stem:bi
# Surface:kitap, Stem:kit
# Surface:duruyormuş, Stem:duruyor
# Surface:içinde, Stem:iç
# Surface:Türkiye, Stem:Türk
# Surface:istikrar, Stem:istikr
# Surface:içinde, Stem:iç
# Surface:güven, Stem:güv
# Surface:içinde, Stem:iç
# Surface:büyüyor, Stem:büy
# Surface:kalkınıyor, Stem:kalk
# Surface:Bunu, Stem:Bu
# Surface:getirmenin, Stem:ge
# Surface:farklı, Stem:fark
# Surface:faydaları, Stem:fayda
# Surface:da, Stem:da
# Surface:var, Stem:va
# Surface:Doktrine, Stem:Dokt
# Surface:olan, Stem:o
# Surface:katkısı, Stem:katkı
# Surface:dolayısıyla, Stem:dolayı
# Surface:ismi, Stem:is
# Surface:sistemle, Stem:siste
# Surface:birlikte, Stem:bir
# Surface:anılmaya, Stem:an
# Surface:getirilen, Stem:ge
# Surface:kültüre, Stem:kültü
# Surface:Marxizm, Stem:Marxiz
# Surface:Leninizm, Stem:Leniniz
# Surface:denilmeye, Stem:den
# Surface:başlandı, Stem:baş
# Surface:de, Stem:de
# Surface:Henry, Stem:Henr
# Surface:gibi, Stem:gi
# Surface:hükümranlığını, Stem:hükümran
# Surface:ve, Stem:ve
# Surface:krallığın, Stem:kral
# Surface:cakasını, Stem:caka
# Surface:en, Stem:en
# Surface:pervasızca, Stem:perva
# Surface:en, Stem:en
# Surface:şımarıkça, Stem:şımar
# Surface:yaşamış, Stem:yaşa
# Surface:bir, Stem:bi
# Surface:kral, Stem:kr
# Surface:bile, Stem:bi
# Surface:Katolik, Stem:Kato
# Surface:karısı, Stem:karı
# Surface:Catherine, Stem:Cath
# Surface:ile, Stem:il
# Surface:sevgilisi, Stem:sevgi
# Surface:Anne, Stem:An
# Surface:Boleyn, Stem:Boley
# Surface:arasındaki, Stem:ara
# Surface:savaşta, Stem:savaş
# Surface:sıkışıp, Stem:sıkış
# Surface:yeni, Stem:ye
# Surface:bir, Stem:bi
# Surface:din, Stem:di
# Surface:icat, Stem:ic
# Surface:etmek, Stem:et
# Surface:ve, Stem:ve
# Surface:bütün, Stem:bü
# Surface:memleketin, Stem:memleke
# Surface:dinini, Stem:di
# Surface:değiştirip, Stem:değiş
# Surface:yıllarca, Stem:yıl
# Surface:bitmeyecek, Stem:bit
# Surface:kanlı, Stem:kan
# Surface:bir, Stem:bi
# Surface:din, Stem:di
# Surface:savaşının, Stem:savaş
# Surface:başlamasına, Stem:başla
# Surface:neden, Stem:ne
# Surface:olmak, Stem:ol
# Surface:zorunda, Stem:zo
# Surface:kalır, Stem:kal
# Surface:Beşir, Stem:Beş
# Surface:kişinin, Stem:kiş
# Surface:öldüğü, Stem:öl
# Surface:kilise, Stem:kili
# Surface:bombalamalarıyla, Stem:bombala
# Surface:ilgili, Stem:ilgi
# Surface:olarak, Stem:o
# Surface:da, Stem:da
# Surface:zanlı, Stem:zan
# Surface:ilan, Stem:il
# Surface:edilmişti, Stem:ed
# Surface:Önce, Stem:Ön
# Surface:Hak, Stem:Ha
# Surface:İş, Stem:İş
# Surface:Genel, Stem:Gene
# Surface:Başkanı, Stem:Başk
# Surface:Necati, Stem:Neca
# Surface:Çelik, Stem:Çe
# Surface:daha, Stem:dah
# Surface:sonra, Stem:son
# Surface:da, Stem:da
# Surface:Türk, Stem:Tür
# Surface:İş, Stem:İş
# Surface:Genel, Stem:Gene
# Surface:Başkanı, Stem:Başk
# Surface:Bayram, Stem:Bayr
# Surface:makamında, Stem:maka
# Surface:kabul, Stem:kabu
# Surface:eden, Stem:ed
# Surface:Halis, Stem:Hali
# Surface:grev, Stem:gr
# Surface:ertelemesine, Stem:ertele
# Surface:başvurulabilmesi, Stem:başvurul
# Surface:için, Stem:iç
# Surface:genel, Stem:gene
# Surface:sağlığı, Stem:sağ
# Surface:ve, Stem:ve
# Surface:kamu, Stem:ka
# Surface:güvenliğini, Stem:güven
# Surface:ilgilendiren, Stem:ilgi
# Surface:haklı, Stem:hak
# Surface:bir, Stem:bi
# Surface:nedenin, Stem:ned
# Surface:olması, Stem:ol
# Surface:gerektiğini, Stem:gerek
# Surface:ifade, Stem:ifa
# Surface:etti, Stem:et
# Surface:II, Stem:II
# Surface:GENÇ, Stem:GENÇ
# Surface:Tut, Stem:Tu
# Surface:onu, Stem:o
# Surface:Dedim, Stem:De
# Surface:ya, Stem:ya
# Surface:taraftar, Stem:taraft
# Surface:yazarların, Stem:yaz
# Surface:yazdıklarından, Stem:yazdık
# Surface:tribünlerin, Stem:tribün
# Surface:ruhsuz, Stem:ruh
# Surface:ibne, Stem:ib
# Surface:sine, Stem:si
# Surface:sıçramak, Stem:sıçra
# Surface:hiç, Stem:hiç
# Surface:zor, Stem:zo
# Surface:değildir, Stem:değil
# Surface:Fakat, Stem:Fak
# Surface:nedense, Stem:neden
# Surface:babamın, Stem:baba
# Surface:umurundaymış, Stem:umurunda
# Surface:Elazığ, Stem:Elazığ
# Surface:yakınlarında, Stem:yakın
# Surface:o, Stem:o
# Surface:sıralarda, Stem:sıra
# Surface:Vertetil, Stem:Vertet
# Surface:adı, Stem:ad
# Surface:verilen, Stem:ve
# Surface:yerde, Stem:yer
# Surface:havaalanının, Stem:havaal
# Surface:yapımı, Stem:yap
# Surface:tamamlandı, Stem:tamam
# Surface:esen, Stem:es
# Surface:fırtınanın, Stem:fırtın
# Surface:bütüncüllüğü, Stem:bütüncül
# Surface:kitleselliği, Stem:kitlesel
# Surface:hoşgörüsü, Stem:hoşgörü
# Surface:kaybolmuştu, Stem:kaybol
# Surface:Ben, Stem:Be
# Surface:de, Stem:de
# Surface:öyle, Stem:öy
# Surface:sanıyordum, Stem:sa
# Surface:Sözde, Stem:Söz
# Surface:devlet, Stem:devle
# Surface:ten, Stem:te
# Surface:yana, Stem:ya
# Surface:olanlarını, Stem:ol
# Surface:sözde, Stem:söz
# Surface:devlet, Stem:devle
# Surface:için, Stem:iç
# Surface:yapılanları, Stem:yapıl
# Surface:meşrulaştırmaya, Stem:meşrulaş
# Surface:çalışıyoruz, Stem:çalış
# Surface:Şu, Stem:Şu
# Surface:önündeki, Stem:ön
# Surface:kumun, Stem:ku
# Surface:bir, Stem:bi
# Surface:tanesiyim, Stem:tanesi
# Surface:Doktora, Stem:Dokto
# Surface:göre, Stem:gö
# Surface:bir, Stem:bi
# Surface:hafta, Stem:haf
# Surface:içinde, Stem:iç
# Surface:geçebilirmiş, Stem:geçebil
# Surface:bu, Stem:bu
# Surface:felç, Stem:felç
# Surface:Organize, Stem:Orga
# Surface:görüntümüz, Stem:görünt
# Surface:hoşlarına, Stem:hoş
# Surface:gitmedi, Stem:gi
# Surface:Teröristler, Stem:Terörist
# Surface:iki, Stem:ik
# Surface:kişiyi, Stem:kişi
# Surface:kaçırdı, Stem:kaç
# Surface:Ferrero, Stem:Ferrer
# Surface:böylece, Stem:böyle
# Surface:Estoril, Stem:Estor
# Surface:ve, Stem:ve
# Surface:sonra, Stem:son
# Surface:toprak, Stem:topr
# Surface:korttaki, Stem:kort
# Surface:sezonun, Stem:sez
# Surface:üçüncü, Stem:üç
# Surface:birinciliğini, Stem:birinci
# Surface:aldı, Stem:al
# Surface:Çünkü, Stem:Çün
# Surface:klinikte, Stem:klinik
# Surface:hekiminden, Stem:hekim
# Surface:çözge, Stem:çöz
# Surface:çare, Stem:ça
# Surface:bekleyen, Stem:bekle
# Surface:hastaların, Stem:hasta
# Surface:dışındadır, Stem:dış
# Surface:bu, Stem:bu
# Surface:olanlar, Stem:ol
# Surface:Ayrıca, Stem:Ayrı
# Surface:sevgilisi, Stem:sevgi
# Surface:de, Stem:de
# Surface:vardı, Stem:va
# Surface:Ağabey, Stem:Ağabe
# Surface:örtüleri, Stem:örtü
# Surface:ütüleyip, Stem:ütüle
# Surface:sana, Stem:sa
# Surface:getirdim, Stem:ge
# Surface:dedi, Stem:de
# Surface:Onun, Stem:On
# Surface:odasının, Stem:oda
# Surface:altındaki, Stem:al
# Surface:odada, Stem:oda
# Surface:yatıyordum, Stem:yat
# Surface:Bağlanmayan, Stem:Bağ
# Surface:telefonlar, Stem:telefo
# Surface:duyulmayan, Stem:duy
# Surface:sesler, Stem:ses
# Surface:geç, Stem:geç
# Surface:giren, Stem:gir
# Surface:görüntüler, Stem:görün
# Surface:istemiyordum, Stem:iste
# Surface:Böyle, Stem:Bö
# Surface:kandırmacalara, Stem:kandırmaca
# Surface:aldanmamalı, Stem:alda
# Surface:sinsi, Stem:sin
# Surface:kışkırtmalara, Stem:kışkırt
# Surface:direnmeliyim, Stem:diren
# Surface:diyorum, Stem:di
# Surface:kendi, Stem:ke
# Surface:kendime, Stem:kend
# Surface:Medyalamacılığın, Stem:Medyalamacı
# Surface:efendisi, Stem:efend
# Surface:olarak, Stem:o
# Surface:baştan, Stem:baş
# Surface:kabul, Stem:kabu
# Surface:etmezsin, Stem:et
# Surface:teklifini, Stem:tekli
# Surface:ya, Stem:ya
# Surface:da, Stem:da
# Surface:iddia, Stem:idd
# Surface:ettiğin, Stem:et
# Surface:kadar, Stem:kad
# Surface:ordinaryüssen, Stem:ordinaryüs
# Surface:o, Stem:o
# Surface:röportajı, Stem:röportaj
# Surface:da, Stem:da
# Surface:idare, Stem:ida
# Surface:etmeyi, Stem:et
# Surface:becerirsin, Stem:becer
# Surface:Beş, Stem:Beş
# Surface:yıl, Stem:yı
# Surface:olmuştu, Stem:ol
# Surface:Sadece, Stem:Sade
# Surface:iki, Stem:ik
# Surface:gün, Stem:gü
# Surface:kalacağımız, Stem:kal
# Surface:için, Stem:iç
# Surface:bir, Stem:bi
# Surface:iki, Stem:ik
# Surface:giyecek, Stem:gi
# Surface:ve, Stem:ve
# Surface:hediye, Stem:hed
# Surface:paketleriyle, Stem:paket
# Surface:yola, Stem:yo
# Surface:koyulduk, Stem:koy
# Surface:CHP, Stem:CHP
# Surface:milletvekillerinin, Stem:milletvekil
# Surface:duruşma, Stem:duru
# Surface:salonunda, Stem:salon
# Surface:izleyicilere, Stem:izley
# Surface:ayrılmış, Stem:ay
# Surface:olan, Stem:o
# Surface:sıralardan, Stem:sıra
# Surface:takip, Stem:tak
# Surface:etme, Stem:et
# Surface:imkânına, Stem:imkâ
# Surface:rağmen, Stem:rağ
# Surface:özellikle, Stem:özel
# Surface:sanık, Stem:sanı
# Surface:müdafilerine, Stem:müdafi
# Surface:ayrılmış, Stem:ay
# Surface:sıralarda, Stem:sıra
# Surface:oturduklarını, Stem:o
# Surface:dile, Stem:di
# Surface:getiren, Stem:ge
# Surface:Savcı, Stem:Sav
# Surface:Pekgüzel, Stem:Pekgüze
# Surface:Şahin, Stem:Şah
# Surface:de, Stem:de
# Surface:kastederek, Stem:kaste
# Surface:istemini, Stem:iste
# Surface:tutanaklara, Stem:tutan
# Surface:şu, Stem:şu
# Surface:sözlerle, Stem:söz
# Surface:geçirdi, Stem:geç
# Surface:Beni, Stem:Be
# Surface:hücreden, Stem:hücr
# Surface:çıkarıp, Stem:çık
# Surface:saçımı, Stem:saç
# Surface:bıyığımı, Stem:bıyı
# Surface:kesip, Stem:kes
# Surface:tek, Stem:te
# Surface:tip, Stem:tip
# Surface:bir, Stem:bi
# Surface:elbise, Stem:elbi
# Surface:giydirerek, Stem:giy
# Surface:koğuşa, Stem:koğ
# Surface:götürdüler, Stem:götür
# Surface:CHP, Stem:CHP
# Surface:Randevu, Stem:Randev
# Surface:talebi, Stem:tale
# Surface:yok, Stem:yo
# Surface:Odunluğun, Stem:Odun
# Surface:dibinde, Stem:di
# Surface:erik, Stem:er
# Surface:ağacı, Stem:ağa
# Surface:Arada, Stem:Ara
# Surface:bir, Stem:bi
# Surface:her, Stem:he
# Surface:çeşitten, Stem:çeşit
# Surface:biraz, Stem:bir
# Surface:karışık, Stem:kar
# Surface:doldurtanlar, Stem:doldurt
# Surface:da, Stem:da
# Surface:olurdu, Stem:ol
# Surface:Fransa, Stem:Fra
# Surface:ve, Stem:ve
# Surface:bir, Stem:bi
# Surface:iki, Stem:ik
# Surface:ülke, Stem:ülk
# Surface:Acil, Stem:Ac
# Surface:Müdahale, Stem:Müdah
# Surface:ileride, Stem:ileri
# Surface:bağımsız, Stem:bağım
# Surface:olmasını, Stem:ol
# Surface:istiyor, Stem:is
# Surface:Beyaz, Stem:Bey
# Surface:zemin, Stem:ze
# Surface:üzerinde, Stem:üz
# Surface:pek, Stem:pe
# Surface:hoş, Stem:hoş
# Surface:gözükmeyen, Stem:gözük
# Surface:toprağı, Stem:topra
# Surface:yerden, Stem:yer
# Surface:temizlerken, Stem:temizl
# Surface:kapıdan, Stem:kapı
# Surface:içeriye, Stem:içer
# Surface:izin, Stem:iz
# Surface:isteyerek, Stem:iste
# Surface:biraz, Stem:bir
# Surface:çekingen, Stem:çeking
# Surface:biraz, Stem:bir
# Surface:kırılgan, Stem:kırılg
# Surface:bir, Stem:bi
# Surface:öğrencim, Stem:öğren
# Surface:girdi, Stem:gi
# Surface:Şimdi, Stem:Şim
# Surface:servisi, Stem:serv
# Surface:siz, Stem:siz
# Surface:yapacaksınız, Stem:yap
# Surface:Yeter, Stem:Yet
# Surface:ki, Stem:ki
# Surface:önemli, Stem:önem
# Surface:olduğunu, Stem:ol
# Surface:düşündüğünüz, Stem:düşün
# Surface:şeyi, Stem:şe
# Surface:iyice, Stem:iyi
# Surface:bir, Stem:bi
# Surface:eleyin, Stem:ele
# Surface:ve, Stem:ve
# Surface:bakın, Stem:ba
# Surface:bakalım, Stem:bak
# Surface:hayatınızın, Stem:hayat
# Surface:gidişatını, Stem:gidişa
# Surface:engelliyor, Stem:engell
# Surface:mu, Stem:mu
# Surface:engellemiyor, Stem:engell
# Surface:mu, Stem:mu
# Surface:Bir, Stem:Bi
# Surface:teknenin, Stem:tekn
# Surface:manevrada, Stem:manevra
# Surface:dönebilmesi, Stem:döneb
# Surface:için, Stem:iç
# Surface:üzerinde, Stem:üz
# Surface:yol, Stem:yo
# Surface:olması, Stem:ol
# Surface:gerekir, Stem:gerek
# Surface:Bol, Stem:Bo
# Surface:kekik, Stem:kek
# Surface:çiğneyin, Stem:çiğne
# Surface:Zirveye, Stem:Zirve
# Surface:bölge, Stem:böl
# Surface:milletvekilleri, Stem:milletvekil
# Surface:valiler, Stem:va
# Surface:belediye, Stem:beled
# Surface:başkanları, Stem:başk
# Surface:sanayi, Stem:sana
# Surface:ticaret, Stem:ticare
# Surface:ve, Stem:ve
# Surface:esnaf, Stem:esnaf
# Surface:odaları, Stem:oda
# Surface:başkanları, Stem:başk
# Surface:bölgenin, Stem:bölg
# Surface:önde, Stem:ön
# Surface:gelen, Stem:ge
# Surface:sivil, Stem:siv
# Surface:toplum, Stem:top
# Surface:kuruluşları, Stem:kur
# Surface:katılacak, Stem:kat
# Surface:Bir, Stem:Bi
# Surface:gün, Stem:gü
# Surface:nasıl, Stem:nas
# Surface:oldu, Stem:ol
# Surface:bilmem, Stem:bil
# Surface:birtakım, Stem:birtak
# Surface:adamlar, Stem:adam
# Surface:geldiler, Stem:gel
# Surface:elektrik, Stem:elektr
# Surface:bağlantılarımı, Stem:bağlantı
# Surface:yapıp, Stem:yap
# Surface:tepeme, Stem:tepe
# Surface:bir, Stem:bi
# Surface:kocaman, Stem:koca
# Surface:ampul, Stem:ampu
# Surface:taktılar, Stem:tak
# Surface:Meğerse, Stem:Meğ
# Surface:ne, Stem:ne
# Surface:kadar, Stem:kad
# Surface:yanılmışız, Stem:yanıl
# Surface:İnsanların, Stem:İns
# Surface:ve, Stem:ve
# Surface:toplulukların, Stem:toplu
# Surface:birbirine, Stem:birbi
# Surface:üstünlüğü, Stem:üstün
# Surface:ve, Stem:ve
# Surface:egemenliği, Stem:egemen
# Surface:o, Stem:o
# Surface:zaman, Stem:za
# Surface:söz, Stem:söz
# Surface:konusu, Stem:konu
# Surface:olmaya, Stem:ol
# Surface:başlar, Stem:baş
# Surface:İstanbul, Stem:İstanbu
# Surface:yapılacak, Stem:yap
# Surface:konsere, Stem:konse
# Surface:Kıraç, Stem:Kıraç
# Surface:Haluk, Stem:Ha
# Surface:Levent, Stem:Leven
# Surface:Bulutsuzluk, Stem:Bulut
# Surface:Özlemi, Stem:Özle
# Surface:Pentagram, Stem:Pentagr
# Surface:Okan, Stem:Ok
# Surface:Karacan, Stem:Karac
# Surface:ve, Stem:ve
# Surface:Nejat, Stem:Nej
# Surface:Yavaşoğulları, Stem:Yavaşoğul
# Surface:ile, Stem:il
# Surface:birçok, Stem:bir
# Surface:sanatçı, Stem:sanat
# Surface:katılacak, Stem:kat
# Surface:Benjamin, Stem:Benja
# Surface:dramından, Stem:dram
# Surface:yaklaşık, Stem:yakl
# Surface:yirmi, Stem:yir
# Surface:beş, Stem:beş
# Surface:yıl, Stem:yı
# Surface:sonra, Stem:son
# Surface:Tamam, Stem:Ta
# Surface:deyip, Stem:de
# Surface:görüşmeye, Stem:görüş
# Surface:gider, Stem:gi
# Surface:H, Stem:H
# Surface:Burada, Stem:Bura
# Surface:insan, Stem:in
# Surface:kendini, Stem:ken
# Surface:unutuyor, Stem:un
# Surface:Dipsiz, Stem:Dip
# Surface:The, Stem:Th
# Surface:Blank, Stem:Blan
# Surface:Wall, Stem:Wal
# Surface:un, Stem:un
# Surface:ikinci, Stem:ik
# Surface:uyarlaması, Stem:uyarla
# Surface:Yaptığın, Stem:Yap
# Surface:hareket, Stem:hareke
# Surface:hiç, Stem:hiç
# Surface:akıllı, Stem:akıl
# Surface:bir, Stem:bi
# Surface:çocuğa, Stem:çocu
# Surface:yakışıyor, Stem:yak
# Surface:mu, Stem:mu
# Surface:Fransa, Stem:Fra
# Surface:Cumhurbaşkanı, Stem:Cumhur
# Surface:Nicolas, Stem:Nicola
# Surface:Sarkozy, Stem:Sarkoz
# Surface:gencin, Stem:gen
# Surface:ölümünden, Stem:ölüm
# Surface:duyduğu, Stem:duy
# Surface:derin, Stem:de
# Surface:üzüntüyü, Stem:üzüntü
# Surface:dile, Stem:di
# Surface:getirdi, Stem:ge
# Surface:Ölümün, Stem:Öl
# Surface:zamandan, Stem:zam
# Surface:alınacak, Stem:al
# Surface:ödünç, Stem:ödünç
# Surface:anların, Stem:an
# Surface:bitmesi, Stem:bi
# Surface:olduğunu, Stem:ol
# Surface:kavrarsın, Stem:kavr
# Surface:Bir, Stem:Bi
# Surface:gün, Stem:gü
# Surface:bir, Stem:bi
# Surface:çiftlik, Stem:çift
# Surface:sahibi, Stem:sahi
# Surface:çıkagelmez, Stem:çıkagel
# Surface:mi, Stem:mi
# Surface:Bendeki, Stem:Be
# Surface:münasebetsizliğe, Stem:münasebetsiz
# Surface:de, Stem:de
# Surface:bakın, Stem:ba
# Surface:bahçede, Stem:bahçe
# Surface:otururlarken, Stem:oturur
# Surface:onun, Stem:o
# Surface:önünde, Stem:ön
# Surface:çişimi, Stem:çiş
# Surface:yapıverdim, Stem:yapıv
# Surface:Aşktan, Stem:Aşk
# Surface:aşkınızdan, Stem:aşkınız
# Surface:utanmak, Stem:uta
# Surface:zorunda, Stem:zo
# Surface:kalırsınız, Stem:kal
# Surface:Herkese, Stem:Herke
# Surface:büyük, Stem:büyü
# Surface:bir, Stem:bi
# Surface:hızla, Stem:hız
# Surface:ulaşarak, Stem:ulaş
# Surface:randevuların, Stem:randevu
# Surface:iptali, Stem:ipt
# Surface:için, Stem:iç
# Surface:de, Stem:de
# Surface:çaba, Stem:ça
# Surface:sarf, Stem:sarf
# Surface:ediliyordu, Stem:ed
# Surface:Dış, Stem:Dış
# Surface:ülkelerde, Stem:ülke
# Surface:saygı, Stem:say
# Surface:gören, Stem:gör
# Surface:bir, Stem:bi
# Surface:devlet, Stem:devle
# Surface:adamıydı, Stem:adam
# Surface:Jonathan, Stem:Jonath
# Surface:Chiang, Stem:Chiang
# Surface:ölünce, Stem:öl
# Surface:kendi, Stem:ke
# Surface:yurduna, Stem:yur
# Surface:döner, Stem:dön
# Surface:Mermi, Stem:Mer
# Surface:kaldırma, Stem:kal
# Surface:vinci, Stem:vi
# Surface:bozulmuş, Stem:boz
# Surface:bir, Stem:bi
# Surface:topla, Stem:top
# Surface:mı, Stem:mı
# Surface:Arada, Stem:Ara
# Surface:en, Stem:en
# Surface:az, Stem:az
# Surface:üç, Stem:üç
# Surface:yüz, Stem:yüz
# Surface:metre, Stem:met
# Surface:vardı, Stem:va
# Surface:Çiftçiydi, Stem:Çiftç
# Surface:ve, Stem:ve
# Surface:eğitimsizdi, Stem:eğitim
# Surface:Bedri, Stem:Bed
# Surface:ile, Stem:il
# Surface:torun, Stem:tor
# Surface:bunu, Stem:bu
# Surface:yaparken, Stem:yap
# Surface:gözlerinden, Stem:göz
# Surface:de, Stem:de
# Surface:yaşlar, Stem:yaş
# Surface:iniyor, Stem:in
# Surface:İlk, Stem:İl
# Surface:kez, Stem:kez
# Surface:tırmandığımız, Stem:tırman
# Surface:bir, Stem:bi
# Surface:eşik, Stem:eş
# Surface:Bu, Stem:Bu
# Surface:ülkede, Stem:ülke
# Surface:hukukun, Stem:hukuk
# Surface:üstün, Stem:üs
# Surface:olacağını, Stem:ol
# Surface:savunmak, Stem:savu
# Surface:temel, Stem:teme
# Surface:esasların, Stem:esas
# Surface:asla, Stem:as
# Surface:kimse, Stem:kim
# Surface:tarafında, Stem:taraf
# Surface:yıpratılamayacağını, Stem:yıprat
# Surface:iddia, Stem:idd
# Surface:etmek, Stem:et
# Surface:kurumsal, Stem:kurum
# Surface:imtiyazları, Stem:imtiyaz
# Surface:reddetmek, Stem:redde
# Surface:acaba, Stem:aca
# Surface:bu, Stem:bu
# Surface:sözünü, Stem:söz
# Surface:ettiğimiz, Stem:et
# Surface:yorumcuların, Stem:yorum
# Surface:savunduğu, Stem:sav
# Surface:şey, Stem:şe
# Surface:değil, Stem:değ
# Surface:midir, Stem:mi
# Surface:Buna, Stem:Bu
# Surface:karşılık, Stem:karş
# Surface:yöneticilerden, Stem:yönet
# Surface:Kolombiyalı, Stem:Kolombiya
# Surface:Pasquali, Stem:Pasqu
# Surface:Mısırlı, Stem:Mısır
# Surface:Hamdi, Stem:Ham
# Surface:Kandil, Stem:Kand
# Surface:ve, Stem:ve
# Surface:Fransız, Stem:Fran
# Surface:Herve, Stem:Herv
# Surface:Bourges, Stem:Bourge
# Surface:yeni, Stem:ye
# Surface:görüşleri, Stem:gör
# Surface:savunanlar, Stem:sav
# Surface:arasında, Stem:ara
# Surface:yer, Stem:ye
# Surface:alıyorlardı, Stem:al
# Surface:başına, Stem:baş
# Surface:gelenlerin, Stem:gel
# Surface:benim, Stem:ben
# Surface:başıma, Stem:baş
# Surface:da, Stem:da
# Surface:gelmemesi, Stem:gel
# Surface:için, Stem:iç
# Surface:insanlardan, Stem:ins
# Surface:saklanmak, Stem:sak
# Surface:zorunda, Stem:zo
# Surface:olduğumu, Stem:ol
# Surface:biliyordum, Stem:bil
# Surface:Onun, Stem:On
# Surface:için, Stem:iç
# Surface:toplumun, Stem:toplu
# Surface:tasvibini, Stem:tasvi
# Surface:sağlayıncaya, Stem:sağla
# Surface:kadar, Stem:kad
# Surface:aradan, Stem:ar
# Surface:bir, Stem:bi
# Surface:asırdan, Stem:asır
# Surface:fazla, Stem:faz
# Surface:bir, Stem:bi
# Surface:zaman, Stem:za
# Surface:geçmesi, Stem:geç
# Surface:gerekmişti, Stem:gerek
# Surface:Oysa, Stem:Oy
# Surface:olağanüstü, Stem:olağanüs
# Surface:açıklaması, Stem:açıkla
# Surface:o, Stem:o
# Surface:zaman, Stem:za
# Surface:ne, Stem:ne
# Surface:kadar, Stem:kad
# Surface:az, Stem:az
# Surface:yardımcı, Stem:yardım
# Surface:araçlara, Stem:araç
# Surface:dayandınlmıştı, Stem:dayandınl
# Surface:Mesela, Stem:Mese
# Surface:öğrencileri, Stem:öğrenc
# Surface:kıyma, Stem:kıy
# Surface:makinesinden, Stem:makine
# Surface:geçirmiş, Stem:geç
# Surface:olmaları, Stem:ol
# Surface:lazım, Stem:laz
# Surface:mezbahalarda, Stem:mezbaha
# Surface:ille, Stem:il
# Surface:abartmak, Stem:abar
# Surface:gerekiyor, Stem:gerek
# Surface:Herkesi, Stem:Herke
# Surface:en, Stem:en
# Surface:ağır, Stem:ağ
# Surface:ithamlar, Stem:itham
# Surface:altında, Stem:al
# Surface:kolaylıkla, Stem:kolay
# Surface:karalayabilirler, Stem:karala
# Surface:Diyelim, Stem:Di
# Surface:Bünye, Stem:Bün
# Surface:büyük, Stem:büyü
# Surface:olduğu, Stem:ol
# Surface:için, Stem:iç
# Surface:büyük, Stem:büyü
# Surface:harfli, Stem:harf
# Surface:evdeki, Stem:ev
# Surface:ya, Stem:ya
# Surface:da, Stem:da
# Surface:yaşlılar, Stem:yaş
# Surface:evindeki, Stem:ev
# Surface:cank, Stem:can
# Surface:miktarına, Stem:mikta
# Surface:alışmış, Stem:al
# Surface:bir, Stem:bi
# Surface:kez, Stem:kez
# Surface:Annemle, Stem:Anne
# Surface:bebeklerime, Stem:bebek
# Surface:elbise, Stem:elbi
# Surface:diker, Stem:dik
# Surface:o, Stem:o
# Surface:elbiseleri, Stem:elbise
# Surface:bebeklerime, Stem:bebek
# Surface:giydirirdim, Stem:giydir
# Surface:Yumurta, Stem:Yumur
# Surface:ve, Stem:ve
# Surface:şekeri, Stem:şeke
# Surface:çırpın, Stem:çırp
# Surface:Birey, Stem:Bire
# Surface:zaman, Stem:za
# Surface:zaman, Stem:za
# Surface:varlığından, Stem:var
# Surface:gelen, Stem:ge
# Surface:buyruklarla, Stem:buyruk
# Surface:katar, Stem:kat
# Surface:ve, Stem:ve
# Surface:düş, Stem:düş
# Surface:gerçek, Stem:gerçe
# Surface:karışımı, Stem:karış
# Surface:bir, Stem:bi
# Surface:dünyada, Stem:dünya
# Surface:gezinir, Stem:gez
# Surface:Sevgili, Stem:Sevgi
# Surface:gençler, Stem:genç
# Surface:Yakınma, Stem:Yak
# Surface:konusu, Stem:konu
# Surface:olan, Stem:o
# Surface:bir, Stem:bi
# Surface:başka, Stem:başk
# Surface:sorun, Stem:sor
# Surface:giyimle, Stem:giy
# Surface:ilgiliydi, Stem:ilgi
# Surface:yüzyılın, Stem:yüzyı
# Surface:önde, Stem:ön
# Surface:gelen, Stem:ge
# Surface:sanatçılarından, Stem:sanatçı
# Surface:en, Stem:en
# Surface:az, Stem:az
# Surface:iki, Stem:ik
# Surface:tablosu, Stem:tablo
# Surface:İspanyol, Stem:İspanyo
# Surface:ressamın, Stem:ressa
# Surface:torunu, Stem:tor
# Surface:Diana, Stem:Di
# Surface:Widmaier, Stem:Widmai
# Surface:evinden, Stem:ev
# Surface:çalındı, Stem:çal
# Surface:İsrail, Stem:İsra
# Surface:çatıştı, Stem:çat
# Surface:Al, Stem:Al
# Surface:telefonum, Stem:telefo
# Surface:gümrük, Stem:gümrü
# Surface:işin, Stem:iş
# Surface:olursa, Stem:ol
# Surface:lazım, Stem:laz
# Surface:olur, Stem:ol
# Surface:Bilir, Stem:Bil
# Surface:misin, Stem:mi
# Surface:çok, Stem:ço
# Surface:iyi, Stem:iy
# Surface:bir, Stem:bi
# Surface:gazeteci, Stem:gazete
# Surface:çok, Stem:ço
# Surface:iyi, Stem:iy
# Surface:bir, Stem:bi
# Surface:dış, Stem:dış
# Surface:politika, Stem:politik
# Surface:yazarı, Stem:yaz
# Surface:ve, Stem:ve
# Surface:çok, Stem:ço
# Surface:iyi, Stem:iy
# Surface:bir, Stem:bi
# Surface:muhabirdin, Stem:muhabir
# Surface:Çeto, Stem:Çet
# Surface:Açılın, Stem:Açı
# Surface:çekilin, Stem:çek
# Surface:gazeteciler, Stem:gazete
# Surface:geliyor, Stem:gel
# Surface:Güçlükle, Stem:Güç
# Surface:doğruldu, Stem:doğr
# Surface:Süpermen, Stem:Süper
# Surface:sırtındaki, Stem:sır
# Surface:patlıcanı, Stem:patlıc
# Surface:el, Stem:el
# Surface:attı, Stem:at
# Surface:çıkardı, Stem:çık
# Surface:Babam, Stem:Bab
# Surface:hürriyet, Stem:hürriye
# Surface:gazetesinde, Stem:gazete
# Surface:Dini, Stem:Di
# Surface:Sohbetler, Stem:Sohbet
# Surface:başlığı, Stem:baş
# Surface:altında, Stem:al
# Surface:Eski, Stem:Es
# Surface:Sivas, Stem:Siva
# Surface:Müftüsü, Stem:Müftü
# Surface:Turan, Stem:Tur
# Surface:Dursun, Stem:Dur
# Surface:imzasıyla, Stem:imza
# Surface:köşe, Stem:köş
# Surface:yazıları, Stem:yazı
# Surface:yazıyordu, Stem:yaz
# Surface:Bir, Stem:Bi
# Surface:toplumda, Stem:topl
# Surface:oruçlular, Stem:oruçlu
# Surface:da, Stem:da
# Surface:bulunur, Stem:bul
# Surface:oruçsuzlar, Stem:oruçsuz
# Surface:da, Stem:da
# Surface:Akşam, Stem:Akş
# Surface:oluyor, Stem:ol
# Surface:ve, Stem:ve
# Surface:güya, Stem:gü
# Surface:bizim, Stem:biz
# Surface:Ulubatlı, Stem:Ulubat
# Surface:ilk, Stem:il
# Surface:defa, Stem:def
# Surface:iniş, Stem:in
# Surface:yapacak, Stem:yap
# Surface:Türk, Stem:Tür
# Surface:sporcular, Stem:spor
# Surface:Avrupa, Stem:Avrup
# Surface:dört, Stem:dör
# Surface:altın, Stem:al
# Surface:iki, Stem:ik
# Surface:gümüş, Stem:gü
# Surface:ve, Stem:ve
# Surface:bir, Stem:bi
# Surface:bronz, Stem:bronz
# Surface:kazanarak, Stem:kaza
# Surface:şampiyonluğu, Stem:şampiyon
# Surface:göğüsledi, Stem:göğüsle
# Surface:Hipotiroidizme, Stem:Hipotiroidiz
# Surface:yol, Stem:yo
# Surface:açan, Stem:aç
# Surface:guatr, Stem:guat
# Surface:vakalarında, Stem:vaka
# Surface:mutlaka, Stem:mutlak
# Surface:tiroid, Stem:tiroi
# Surface:hormonu, Stem:hormo
# Surface:verilmesi, Stem:ver
# Surface:gereklidir, Stem:gerek
# Surface:Belki, Stem:Bel
# Surface:yüzyıl, Stem:yüzy
# Surface:yaşayan, Stem:yaşa
# Surface:birinden, Stem:bi
# Surface:daha, Stem:dah
# Surface:çok, Stem:ço
# Surface:soluk, Stem:so
# Surface:alıp, Stem:al
# Surface:vermek, Stem:ver
# Surface:zorunda, Stem:zo
# Surface:kaldı, Stem:kal
# Surface:dünyanın, Stem:dün
# Surface:temiz, Stem:te
# Surface:havası, Stem:hav
# Surface:yetersizdi, Stem:yeter
# Surface:tüm, Stem:tü
# Surface:dünya, Stem:dün
# Surface:temiz, Stem:te
# Surface:havaya, Stem:hava
# Surface:kavuşunca, Stem:kavuş
# Surface:astım, Stem:as
# Surface:dinebilir, Stem:di
# Surface:ruh, Stem:ru
# Surface:dinginliğine, Stem:dingin
# Surface:kavuşabilirdi, Stem:kavuş
# Surface:Silahını, Stem:Sil
# Surface:bırakmakla, Stem:bırak
# Surface:bırakmamak, Stem:bırak
# Surface:evine, Stem:ev
# Surface:dönmekle, Stem:dön
# Surface:dönmemek, Stem:dön
# Surface:arasında, Stem:ara
# Surface:bocalıyordun, Stem:bocalıyor
# Surface:Bu, Stem:Bu
# Surface:açıdan, Stem:açı
# Surface:stratejik, Stem:strate
# Surface:zafer, Stem:zaf
# Surface:getiren, Stem:ge
# Surface:her, Stem:he
# Surface:can, Stem:ca
# Surface:alıcı, Stem:al
# Surface:noktada, Stem:nokta
# Surface:kendisini, Stem:kendi
# Surface:ölüme, Stem:öl
# Surface:yatırmayarak, Stem:yatırma
# Surface:savaşı, Stem:savaş
# Surface:mihenk, Stem:mihen
# Surface:taşında, Stem:taş
# Surface:değil, Stem:değ
# Surface:geride, Stem:geri
# Surface:talide, Stem:tali
# Surface:vermeyi, Stem:ver
# Surface:esas, Stem:esa
# Surface:alır, Stem:al
# Surface:Oniki, Stem:Oni
# Surface:parmak, Stem:par
# Surface:bağırsağındaki, Stem:bağırsa
# Surface:yaralara, Stem:yara
# Surface:iyi, Stem:iy
# Surface:gelir, Stem:gel
# Surface:Bu, Stem:Bu
# Surface:belki, Stem:bel
# Surface:de, Stem:de
# Surface:mümkündür, Stem:mümkün
# Surface:ama, Stem:am
# Surface:o, Stem:o
# Surface:sessizlik, Stem:ses
# Surface:nasıl, Stem:nas
# Surface:anlatılabilir, Stem:anlat
# Surface:Ancak, Stem:Anc
# Surface:bir, Stem:bi
# Surface:insanın, Stem:ins
# Surface:başka, Stem:başk
# Surface:bir, Stem:bi
# Surface:insanla, Stem:ins
# Surface:imtihanı, Stem:imtih
# Surface:gerçekten, Stem:gerçek
# Surface:en, Stem:en
# Surface:zor, Stem:zo
# Surface:olanıdır, Stem:ol
# Surface:temasları, Stem:temas
# Surface:çerçevesinde, Stem:çerçeve
# Surface:İlk, Stem:İl
# Surface:olarak, Stem:o
# Surface:MGK, Stem:MGK
# Surface:Genel, Stem:Gene
# Surface:Sekreteri, Stem:Sekrete
# Surface:Yiğit, Stem:Yiği
# Surface:Alpogan, Stem:Alpog
# Surface:ile, Stem:il
# Surface:görüşen, Stem:gör
# Surface:Laricani, Stem:Laric
# Surface:daha, Stem:dah
# Surface:sonra, Stem:son
# Surface:Başbakan, Stem:Başba
# Surface:Recep, Stem:Recep
# Surface:Tayyip, Stem:Tay
# Surface:Erdoğan, Stem:Erdoğ
# Surface:ve, Stem:ve
# Surface:Dışişleri, Stem:Dış
# Surface:Bakanı, Stem:Bak
# Surface:Abdullah, Stem:Abdulla
# Surface:Gül, Stem:Gü
# Surface:ile, Stem:il
# Surface:bir, Stem:bi
# Surface:araya, Stem:ara
# Surface:geldi, Stem:gel
# Surface:KKTC, Stem:KKTC
# Surface:Başbakanı, Stem:Başbak
# Surface:Mehmet, Stem:Mehme
# Surface:Ali, Stem:Al
# Surface:Talat, Stem:Tal
# Surface:çözüme, Stem:çöz
# Surface:ulaşılması, Stem:ulaş
# Surface:için, Stem:iç
# Surface:adım, Stem:ad
# Surface:atması, Stem:at
# Surface:gerekenin, Stem:gerek
# Surface:Rum, Stem:Ru
# Surface:tarafı, Stem:tara
# Surface:olduğunu, Stem:ol
# Surface:belirterek, Stem:belir
# Surface:Atatürk, Stem:Atatür
# Surface:kendimi, Stem:ken
# Surface:mi, Stem:mi
# Surface:asayım, Stem:as
# Surface:Kıbrıs, Stem:Kıbrı
# Surface:Rumları, Stem:Rum
# Surface:için, Stem:iç
# Surface:yapabileceğim, Stem:yap
# Surface:başka, Stem:başk
# Surface:bir, Stem:bi
# Surface:şey, Stem:şe
# Surface:kalmadı, Stem:kal
# Surface:dedi, Stem:de
# Surface:mezarına, Stem:meza
# Surface:birer, Stem:bir
# Surface:kürek, Stem:küre
# Surface:de, Stem:de
# Surface:kendileri, Stem:kend
# Surface:için, Stem:iç
# Surface:toprak, Stem:topr
# Surface:atılmasını, Stem:at
# Surface:istiyorlardı, Stem:ist
# Surface:O, Stem:O
# Surface:kaynaklara, Stem:kayn
# Surface:göre, Stem:gö
# Surface:Nikola, Stem:Niko
# Surface:Alibrandi, Stem:Alibra
# Surface:heptatlonda, Stem:heptatlo
# Surface:olmuş, Stem:o
# Surface:Yorgo, Stem:Yorg
# Surface:ise, Stem:is
# Surface:m, Stem:m
# Surface:halat, Stem:hal
# Surface:tırmanmada, Stem:tırman
# Surface:saniye, Stem:san
# Surface:ile, Stem:il
# Surface:dünya, Stem:dün
# Surface:rekoru, Stem:rekor
# Surface:kırarak, Stem:kır
# Surface:altın, Stem:al
# Surface:madalya, Stem:madal
# Surface:kazanmış, Stem:kaza
# Surface:Türklerin, Stem:Türk
# Surface:ve, Stem:ve
# Surface:Fransızların, Stem:Fran
# Surface:ulusal, Stem:ulu
# Surface:çiçeği, Stem:çiçe
# Surface:İki, Stem:İk
# Surface:arkadaş, Stem:arkadaş
# Surface:birbirini, Stem:birbi
# Surface:neden, Stem:ne
# Surface:kardeş, Stem:kardeş
# Surface:yerine, Stem:ye
# Surface:koyarmış, Stem:koy
# Surface:İçimize, Stem:İç
# Surface:doya, Stem:do
# Surface:doya, Stem:do
# Surface:çekerdik, Stem:çeker
# Surface:bu, Stem:bu
# Surface:var, Stem:va
# Surface:oluşun, Stem:ol
# Surface:kokusunu, Stem:koku
# Surface:O, Stem:O
# Surface:yüzden, Stem:yüz
# Surface:hava, Stem:hav
# Surface:karardıktan, Stem:kar
# Surface:sonra, Stem:son
# Surface:hiçbirini, Stem:hiçbi
# Surface:kaçırmadan, Stem:kaçır
# Surface:bütün, Stem:bü
# Surface:yıldızları, Stem:yıldız
# Surface:aynı, Stem:ay
# Surface:anda, Stem:an
# Surface:görebiliyorsunuz, Stem:gör
# Surface:Bu, Stem:Bu
# Surface:eserde, Stem:eser
# Surface:mantıki, Stem:mantı
# Surface:bir, Stem:bi
# Surface:sezişle, Stem:sez
# Surface:ortaya, Stem:orta
# Surface:koyduğu, Stem:koy
# Surface:prensiplerin, Stem:prensip
# Surface:bir, Stem:bi
# Surface:kısmının, Stem:kıs
# Surface:bugünün, Stem:bug
# Surface:modern, Stem:moder
# Surface:bilgilerine, Stem:bilgi
# Surface:uygun, Stem:uyg
# Surface:olduğu, Stem:ol
# Surface:da, Stem:da
# Surface:bir, Stem:bi
# Surface:gerçektir, Stem:gerçek
# Surface:Herkesin, Stem:Her
# Surface:bir, Stem:bi
# Surface:işi, Stem:iş
# Surface:var, Stem:va
# Surface:Lambaları, Stem:Lamba
# Surface:yakmışlardı, Stem:yak
# Surface:Hepsi, Stem:Hep
# Surface:de, Stem:de
# Surface:esmer, Stem:esm
# Surface:karıştırırım, Stem:karış
# Surface:diyor, Stem:di
# Surface:Bu, Stem:Bu
# Surface:nedenle, Stem:neden
# Surface:Türk, Stem:Tür
# Surface:Tarih, Stem:Tari
# Surface:Kurumunu, Stem:Kurum
# Surface:kurduk, Stem:ku
# Surface:Konu, Stem:Ko
# Surface:komşusu, Stem:komşu
# Surface:severdi, Stem:sev
# Surface:hani, Stem:ha
# Surface:Eğer, Stem:Eğ
# Surface:bunu, Stem:bu
# Surface:kabul, Stem:kabu
# Surface:etmiyorsa, Stem:etm
# Surface:o, Stem:o
# Surface:zaman, Stem:za
# Surface:ödün, Stem:öd
# Surface:vermemizden, Stem:verme
# Surface:başka, Stem:başk
# Surface:çare, Stem:ça
# Surface:yoktu, Stem:yok
# Surface:çünkü, Stem:çün
# Surface:sandalye, Stem:sandal
# Surface:ile, Stem:il
# Surface:bir, Stem:bi
# Surface:üyesini, Stem:üye
# Surface:Meclis, Stem:Mecli
# Surface:Başkanı, Stem:Başk
# Surface:seçtirmeye, Stem:seç
# Surface:gücümüz, Stem:güc
# Surface:yetmeyecekti, Stem:yetmey
# Surface:Bu, Stem:Bu
# Surface:akşamınan, Stem:akşam
# Surface:bir, Stem:bi
# Surface:yel, Stem:ye
# Surface:çıkacağına, Stem:çık
# Surface:dalaletti, Stem:dalale
# Surface:Uşak, Stem:Uş
# Surface:Organize, Stem:Orga
# Surface:Sanayi, Stem:Sana
# Surface:Bölgesi, Stem:Bölge
# Surface:Başkanı, Stem:Başk
# Surface:Zeki, Stem:Ze
# Surface:Boz, Stem:Boz
# Surface:ise, Stem:is
# Surface:Uşak, Stem:Uş
# Surface:Valiliği, Stem:Va
# Surface:Uşak, Stem:Uş
# Surface:Defterdarlığı, Stem:Defterdar
# Surface:Uşak, Stem:Uş
# Surface:Ticaret, Stem:Ticare
# Surface:ve, Stem:ve
# Surface:Sanayi, Stem:Sana
# Surface:Odası, Stem:Od
# Surface:ile, Stem:il
# Surface:Organize, Stem:Orga
# Surface:Sanayi, Stem:Sana
# Surface:Bölgesi, Stem:Bölge
# Surface:yetkililerinin, Stem:yetki
# Surface:bir, Stem:bi
# Surface:araya, Stem:ara
# Surface:gelerek, Stem:gel
# Surface:oluşturduğu, Stem:oluş
# Surface:büroda, Stem:büro
# Surface:yatırım, Stem:yat
# Surface:yapmak, Stem:yap
# Surface:isteyen, Stem:iste
# Surface:sanayicilere, Stem:sanay
# Surface:yön, Stem:yö
# Surface:vereceklerini, Stem:ver
# Surface:söyledi, Stem:söyle
# Surface:Süvari, Stem:Süva
# Surface:Alayı, Stem:Ala
# Surface:emniyet, Stem:emniye
# Surface:düzeni, Stem:düz
# Surface:içinde, Stem:iç
# Surface:ilerlemektedir, Stem:ilerle
# Surface:Kurusun, Stem:Kur
# Surface:bu, Stem:bu
# Surface:senin, Stem:se
# Surface:dedi, Stem:de
# Surface:yanındaki, Stem:yan
# Surface:küçük, Stem:küçü
# Surface:kıza, Stem:kız
# Surface:Kimse, Stem:Kim
# Surface:bana, Stem:ba
# Surface:bir, Stem:bi
# Surface:şey, Stem:şe
# Surface:sormasa, Stem:sor
# Surface:Hindistan, Stem:Hindis
# Surface:çok, Stem:ço
# Surface:farklı, Stem:fark
# Surface:dinlere, Stem:din
# Surface:ve, Stem:ve
# Surface:mezheplere, Stem:mezhep
# Surface:mensup, Stem:mens
# Surface:neredeyse, Stem:nere
# Surface:bir, Stem:bi
# Surface:milyara, Stem:milya
# Surface:yakın, Stem:ya
# Surface:insanın, Stem:ins
# Surface:yaşadığı, Stem:yaşa
# Surface:çok, Stem:ço
# Surface:kalabalık, Stem:kalaba
# Surface:ve, Stem:ve
# Surface:çok, Stem:ço
# Surface:renkli, Stem:renk
# Surface:bir, Stem:bi
# Surface:nüfusu, Stem:nüfu
# Surface:Kuzeyden, Stem:Kuzey
# Surface:Güneye, Stem:Güne
# Surface:Himalaya, Stem:Himala
# Surface:dağlarından, Stem:dağ
# Surface:Hint, Stem:Hin
# Surface:Okyanusuna, Stem:Okyanu
# ...
# Surface:anlaşılınca, Stem:anlaş
# Surface:ben, Stem:be
# Surface:üzülmeyeyim, Stem:üzül
# Surface:diye, Stem:di
# Surface:düğünün, Stem:dü
# Surface:ailesinin, Stem:ail
# Surface:villasında, Stem:villa
# Surface:yapılması, Stem:yap
# Surface:kararlaştırıldı, Stem:karar
# Surface:Sağlık, Stem:Sağ
# Surface:İçin, Stem:İç
# Surface:Zararlı, Stem:Zar
# Surface:Olan, Stem:Ol
# Surface:Bazı, Stem:Ba
# Surface:Maddelerin, Stem:Madde
# Surface:Sularda, Stem:Su
# Surface:Bulunmasına, Stem:Bulu
# Surface:Müsaade, Stem:Müsaa
# Surface:Edilebilen, Stem:Ed
# Surface:Maksimum, Stem:Maksim
# Surface:Değerler, Stem:Değ
# Surface:Düzenli, Stem:Düzen
# Surface:cilt, Stem:cil
# Surface:saç, Stem:saç
# Surface:ve, Stem:ve
# Surface:tırnak, Stem:tırn
# Surface:bakımı, Stem:ba
# Surface:yaptırıyor, Stem:yap
# Surface:yeni, Stem:ye
# Surface:saç, Stem:saç
# Surface:modelleri, Stem:model
# Surface:deniyor, Stem:de
# Surface:ve, Stem:ve
# Surface:jöle, Stem:jö
# Surface:sürüyorlar, Stem:sür
# Surface:Güzelliklere, Stem:Güzel
# Surface:hayrandır, Stem:hayr
# Surface:Soğumadan, Stem:Soğu
# Surface:servis, Stem:servi
# Surface:yapın, Stem:yap
# Surface:Kötü, Stem:Kö
# Surface:bir, Stem:bi
# Surface:öğretmen, Stem:öğret
# Surface:tüm, Stem:tü
# Surface:öğretmenler, Stem:öğret
# Surface:hakkındaki, Stem:hak
# Surface:düşüncelerimizi, Stem:düşünce
# Surface:ve, Stem:ve
# Surface:belki, Stem:bel
# Surface:de, Stem:de
# Surface:bütün, Stem:bü
# Surface:eğitim, Stem:eği
# Surface:yaşamımızı, Stem:yaşam
# Surface:olumsuz, Stem:olum
# Surface:etkileyebiliyor, Stem:etkiley
# Surface:Ama, Stem:Am
# Surface:ben, Stem:be
# Surface:hala, Stem:ha
# Surface:bulamadım, Stem:bul
# Surface:cevabını, Stem:ceva
# Surface:belki, Stem:bel
# Surface:bir, Stem:bi
# Surface:başkası, Stem:başk
# Surface:bulup, Stem:bul
# Surface:anlatacak, Stem:anla
# Surface:Eğilince, Stem:Eğ
# Surface:adamın, Stem:ada
# Surface:götü, Stem:gö
# Surface:açığa, Stem:açı
# Surface:çıkıyor, Stem:çık
# Surface:Su, Stem:Su
# Surface:miktarında, Stem:mikt
# Surface:yılda, Stem:yıl
# Surface:ortalama, Stem:ortala
# Surface:metrelik, Stem:metr
# Surface:düşüş, Stem:düş
# Surface:yaşanırken, Stem:yaşa
# Surface:önlem, Stem:önle
# Surface:alınmazsa, Stem:alın
# Surface:yıl, Stem:yı
# Surface:içinde, Stem:iç
# Surface:bölgedeki, Stem:bölge
# Surface:göllerin, Stem:göl
# Surface:tamamen, Stem:tama
# Surface:kuruyacağı, Stem:kuru
# Surface:bildirildi, Stem:bil
# Surface:de, Stem:de
# Surface:ciddi, Stem:cid
# Surface:bir, Stem:bi
# Surface:kırılma, Stem:kı
# Surface:olur, Stem:ol
# Surface:Kalp, Stem:Kalp
# Surface:masajına, Stem:masaj
# Surface:kan, Stem:ka
# Surface:dolaşımının, Stem:dolaşı
# Surface:geri, Stem:ge
# Surface:geldiği, Stem:gel
# Surface:nabız, Stem:nab
# Surface:kontrolü, Stem:kontro
# Surface:ile, Stem:il
# Surface:fark, Stem:far
# Surface:edilene, Stem:ed
# Surface:kadar, Stem:kad
# Surface:devam, Stem:dev
# Surface:edilir, Stem:ed
# Surface:Telekomünikasyon, Stem:Telekomünikasyo
# Surface:Kurumu, Stem:Kur
# Surface:Başkanı, Stem:Başk
# Surface:Tayfun, Stem:Tayf
# Surface:Acarer, Stem:Acar
# Surface:cep, Stem:cep
# Surface:telefonu, Stem:telefo
# Surface:işletmecilerinin, Stem:işletmeci
# Surface:nüfusu, Stem:nüfu
# Surface:üç, Stem:üç
# Surface:binden, Stem:bi
# Surface:fazla, Stem:faz
# Surface:olan, Stem:o
# Surface:tüm, Stem:tü
# Surface:yerleşim, Stem:yerleş
# Surface:birimlerini, Stem:birim
# Surface:kapsama, Stem:kapsa
# Surface:alanına, Stem:al
# Surface:dahil, Stem:dah
# Surface:ettiğini, Stem:et
# Surface:kaydederek, Stem:kayde
# Surface:nüfusu, Stem:nüfu
# Surface:binin, Stem:bi
# Surface:üstünde, Stem:üst
# Surface:bulunan, Stem:bul
# Surface:tüm, Stem:tü
# Surface:yerleşim, Stem:yerleş
# Surface:birimlerin, Stem:birim
# Surface:işletmeciler, Stem:işletme
# Surface:tarafından, Stem:taraf
# Surface:kapsam, Stem:kap
# Surface:içine, Stem:iç
# Surface:dahil, Stem:dah
# Surface:edilmesini, Stem:ed
# Surface:istedi, Stem:iste
# Surface:Yargılamak, Stem:Yargıla
# Surface:bana, Stem:ba
# Surface:düşmez, Stem:düş
# Surface:yarım, Stem:ya
# Surface:bardak, Stem:bard
# Surface:su, Stem:su
# Surface:Atatürk, Stem:Atatür
# Surface:gülmüş, Stem:gül
# Surface:Çevresindekilere, Stem:Çevresinde
# Surface:Maslahatgüzarım, Stem:Maslahatgüz
# Surface:Yanlış, Stem:Yanl
# Surface:anlamayın, Stem:anla
# Surface:Bu, Stem:Bu
# Surface:nedir, Stem:ne
# Surface:ise, Stem:is
# Surface:bunun, Stem:bu
# Surface:yapılışı, Stem:yap
# Surface:çok, Stem:ço
# Surface:daha, Stem:dah
# Surface:farklı, Stem:fark
# Surface:ve, Stem:ve
# Surface:çok, Stem:ço
# Surface:daha, Stem:dah
# Surface:iyi, Stem:iy
# Surface:et, Stem:et
# Surface:veriyor, Stem:ver
# Surface:zira, Stem:zi
# Surface:buzağı, Stem:buza
# Surface:önce, Stem:ön
# Surface:anne, Stem:an
# Surface:sütüyle, Stem:süt
# Surface:beslenip, Stem:bes
# Surface:ay, Stem:ay
# Surface:ardından, Stem:ar
# Surface:çayıra, Stem:çayı
# Surface:çıkarılıyor, Stem:çık
# Surface:ay, Stem:ay
# Surface:ve, Stem:ve
# Surface:en, Stem:en
# Surface:son, Stem:so
# Surface:çit, Stem:çi
# Surface:padok, Stem:pado
# Surface:içinde, Stem:iç
# Surface:tahıl, Stem:tah
# Surface:ile, Stem:il
# Surface:besleniyor, Stem:bes
# Surface:ay, Stem:ay
# Surface:Çalışması, Stem:Çalı
# Surface:ile, Stem:il
# Surface:kendinden, Stem:ken
# Surface:zeki, Stem:ze
# Surface:öğrencilerden, Stem:öğren
# Surface:daha, Stem:dah
# Surface:fazla, Stem:faz
# Surface:başarı, Stem:baş
# Surface:gösterir, Stem:göster
# Surface:Ama, Stem:Am
# Surface:alıcıya, Stem:al
# Surface:yani, Stem:ya
# Surface:halka, Stem:halk
# Surface:ulaştı, Stem:ula
# Surface:mı, Stem:mı
# Surface:bunlar, Stem:bu
# Surface:Hayır, Stem:Hay
# Surface:Konser, Stem:Kons
# Surface:vermek, Stem:ver
# Surface:için, Stem:iç
# Surface:salon, Stem:salo
# Surface:bulamıyoruz, Stem:bul
# Surface:Çok, Stem:Ço
# Surface:başarılı, Stem:başarı
# Surface:bir, Stem:bi
# Surface:oyuncu, Stem:oyun
# Surface:olan, Stem:o
# Surface:futbolcu, Stem:futbol
# Surface:koşulların, Stem:koşul
# Surface:değişimi, Stem:değ
# Surface:ile, Stem:il
# Surface:sezonu, Stem:sezo
# Surface:kapatmak, Stem:kapa
# Surface:zorunda, Stem:zo
# Surface:kalır, Stem:kal
# Surface:ve, Stem:ve
# Surface:başarı, Stem:baş
# Surface:bir, Stem:bi
# Surface:anda, Stem:an
# Surface:başarısızlığa, Stem:başarı
# Surface:dönüşebilir, Stem:dön
# Surface:Tüketim, Stem:Tüke
# Surface:alışkanlıklarında, Stem:alışkanlık
# Surface:da, Stem:da
# Surface:büyük, Stem:büyü
# Surface:benzerlikler, Stem:benzer
# Surface:görülür, Stem:gör
# Surface:Ya, Stem:Ya
# Surface:bu, Stem:bu
# Surface:çocuk, Stem:çoc
# Surface:bir, Stem:bi
# Surface:gün, Stem:gü
# Surface:dadısıyla, Stem:dadı
# Surface:dolaşmaya, Stem:do
# Surface:çıkar, Stem:çık
# Surface:da, Stem:da
# Surface:o, Stem:o
# Surface:derin, Stem:de
# Surface:nehre, Stem:neh
# Surface:düşüp, Stem:düş
# Surface:boğulursa, Stem:boğul
# Surface:Zavallılar, Stem:Zaval
# Surface:biricik, Stem:biri
# Surface:çocuklarını, Stem:çocuk
# Surface:kaybetmeleri, Stem:kaybe
# Surface:gerçekten, Stem:gerçek
# Surface:çok, Stem:ço
# Surface:feci, Stem:fe
# Surface:Neşe, Stem:Neş
# Surface:hayal, Stem:hay
# Surface:ve, Stem:ve
# Surface:heyecan, Stem:heyec
# Surface:içinde, Stem:iç
# Surface:geçen, Stem:geç
# Surface:bir, Stem:bi
# Surface:gençlik, Stem:genç
# Surface:başlangıcı, Stem:başlang
# Surface:değil, Stem:değ
# Surface:yaşlılığın, Stem:yaşlı
# Surface:başlangıcıydı, Stem:başlangı
# Surface:sanki, Stem:san
# Surface:Güvenlik, Stem:Güven
# Surface:kamera, Stem:kame
# Surface:setinizi, Stem:set
# Surface:kurduktan, Stem:kur
# Surface:sonra, Stem:son
# Surface:çevrimiçi, Stem:çevrimi
# Surface:olarak, Stem:o
# Surface:ücretsiz, Stem:ücret
# Surface:bir, Stem:bi
# Surface:hesap, Stem:hes
# Surface:açabilirsiniz, Stem:aç
# Surface:Bir, Stem:Bi
# Surface:tuhaf, Stem:tuhaf
# Surface:iklim, Stem:ikl
# Surface:yanı, Stem:ya
# Surface:başınızda, Stem:baş
# Surface:tarifsiz, Stem:tarif
# Surface:imbatları, Stem:imbat
# Surface:alıp, Stem:al
# Surface:götürürdü, Stem:götür
# Surface:körfezin, Stem:körfez
# Surface:derinliklerinden, Stem:derinlik
# Surface:Onu, Stem:On
# Surface:sarayın, Stem:sara
# Surface:baş, Stem:baş
# Surface:mimarı, Stem:mim
# Surface:yaptı, Stem:yap
# Surface:O, Stem:O
# Surface:zaman, Stem:za
# Surface:seksen, Stem:sek
# Surface:beş, Stem:beş
# Surface:eder, Stem:ed
# Surface:Mehtabın, Stem:Meht
# Surface:şavkı, Stem:şav
# Surface:vurmuştu, Stem:vur
# Surface:okulun, Stem:oku
# Surface:bahçesine, Stem:bahçe
# Surface:Bizim, Stem:Biz
# Surface:millet, Stem:mille
# Surface:tarihi, Stem:tarih
# Surface:boyunca, Stem:bo
# Surface:gittiği, Stem:gi
# Surface:yerlerde, Stem:yer
# Surface:insanlık, Stem:insa
# Surface:öğretmiş, Stem:öğret
# Surface:kimsenin, Stem:kims
# Surface:diline, Stem:di
# Surface:dinine, Stem:di
# Surface:kültürüne, Stem:kültür
# Surface:dokunmamış, Stem:doku
# Surface:değişik, Stem:değ
# Surface:kavimler, Stem:kavim
# Surface:arasında, Stem:ara
# Surface:bile, Stem:bi
# Surface:barışı, Stem:bar
# Surface:sağlamıştı, Stem:sağla
# Surface:Bu, Stem:Bu
# Surface:takdirde, Stem:takdir
# Surface:varılan, Stem:va
# Surface:sonuç, Stem:sonuç
# Surface:genellikle, Stem:genel
# Surface:aynı, Stem:ay
# Surface:olur, Stem:ol
# Surface:Ona, Stem:On
# Surface:karşı, Stem:karş
# Surface:açılmış, Stem:aç
# Surface:bir, Stem:bi
# Surface:savaşın, Stem:savaş
# Surface:var, Stem:va
# Surface:olduğunu, Stem:ol
# Surface:gösterir, Stem:göster
# Surface:Yatağından, Stem:Yata
# Surface:kalktı, Stem:kalk
# Surface:Tatmak, Stem:Ta
# Surface:dışında, Stem:dış
# Surface:içki, Stem:iç
# Surface:içmiyor, Stem:iç
# Surface:Grupta, Stem:Grup
# Surface:ardından, Stem:ar
# Surface:ikinci, Stem:ik
# Surface:olan, Stem:o
# Surface:millilerimiz, Stem:milli
# Surface:İrlanda, Stem:İrl
# Surface:Cumhuriyeti, Stem:Cumhuriye
# Surface:ile, Stem:il
# Surface:oynadığı, Stem:oyna
# Surface:eleme, Stem:ele
# Surface:maçından, Stem:maç
# Surface:zaferle, Stem:zafer
# Surface:ayrılarak, Stem:ayr
# Surface:tarihinde, Stem:tarih
# Surface:ikinci, Stem:ik
# Surface:kez, Stem:kez
# Surface:finallere, Stem:final
# Surface:yükselme, Stem:yüksel
# Surface:başarısını, Stem:başarı
# Surface:gösterdi, Stem:göst
# Surface:Demek, Stem:De
# Surface:ki, Stem:ki
# Surface:deveci, Stem:deve
# Surface:devenin, Stem:dev
# Surface:başını, Stem:baş
# Surface:çekip, Stem:çek
# Surface:gittiğinde, Stem:git
# Surface:çok, Stem:ço
# Surface:sigara, Stem:siga
# Surface:içtiğinden, Stem:iç
# Surface:deve, Stem:dev
# Surface:dumana, Stem:du
# Surface:alışmış, Stem:al
# Surface:Daha, Stem:Dah
# Surface:az, Stem:az
# Surface:tanıdığımız, Stem:tanı
# Surface:bir, Stem:bi
# Surface:süreç, Stem:süreç
# Surface:tarihçilerin, Stem:tarih
# Surface:ve, Stem:ve
# Surface:kazıbilimcilerin, Stem:kazıbilim
# Surface:filologların, Stem:filolog
# Surface:ve, Stem:ve
# Surface:uygarlık, Stem:uyg
# Surface:tarihçilerinin, Stem:tarihçi
# Surface:son, Stem:so
# Surface:yüzyılın, Stem:yüzyı
# Surface:getirileri, Stem:getir
# Surface:kazanımları, Stem:kazanım
# Surface:ile, Stem:il
# Surface:katettikleri, Stem:kate
# Surface:mesafedir, Stem:mesafe
# Surface:kaptanlık, Stem:kapta
# Surface:konusunda, Stem:konu
# Surface:tecrübeleri, Stem:tecrübe
# Surface:bulunan, Stem:bul
# Surface:Kamerunlu, Stem:Kamerun
# Surface:Rigobert, Stem:Rigober
# Surface:Song, Stem:Song
# Surface:Egemen, Stem:Ege
# Surface:Korkmaz, Stem:Kork
# Surface:ve, Stem:ve
# Surface:Tony, Stem:Ton
# Surface:Sylva, Stem:Sylv
# Surface:da, Stem:da
# Surface:öne, Stem:ön
# Surface:çıkan, Stem:çı
# Surface:isimler, Stem:isim
# Surface:arasında, Stem:ara
# Surface:yer, Stem:ye
# Surface:alıyor, Stem:al
# Surface:YARALILARIN, Stem:YARALILARIN
# Surface:TAŞINMASI, Stem:TAŞINMASI
# Surface:Yurda, Stem:Yur
# Surface:gelmesindeki, Stem:gel
# Surface:amacı, Stem:ama
# Surface:arkadaşını, Stem:arkadaş
# Surface:bir, Stem:bi
# Surface:gün, Stem:gü
# Surface:sonra, Stem:son
# Surface:yapılacak, Stem:yap
# Surface:nişan, Stem:niş
# Surface:törenine, Stem:töre
# Surface:çağırmaktı, Stem:çağır
# Surface:Sabah, Stem:Saba
# Surface:alışverişe, Stem:alışver
# Surface:çıkarken, Stem:çık
# Surface:annem, Stem:anne
# Surface:NATO, Stem:NATO
# Surface:anlaşmasının, Stem:anlaş
# Surface:maddesi, Stem:madde
# Surface:Üye, Stem:Üy
# Surface:ülkelerin, Stem:ülke
# Surface:topraklarına, Stem:topr
# Surface:yönelik, Stem:yön
# Surface:saldırılara, Stem:saldırı
# Surface:karşı, Stem:karş
# Surface:ortak, Stem:or
# Surface:savunmayı, Stem:sav
# Surface:öngörüyor, Stem:ön
# Surface:Ama, Stem:Am
# Surface:bütün, Stem:bü
# Surface:marifetlerine, Stem:marifet
# Surface:rağmen, Stem:rağ
# Surface:bir, Stem:bi
# Surface:makinedir, Stem:mak
# Surface:o, Stem:o
# Surface:Bunun, Stem:Bu
# Surface:yanında, Stem:ya
# Surface:etrafındaki, Stem:etraf
# Surface:bütün, Stem:bü
# Surface:bu, Stem:bu
# Surface:insanlarla, Stem:ins
# Surface:barışık, Stem:bar
# Surface:olmayı, Stem:ol
# Surface:da, Stem:da
# Surface:başarmalıdır, Stem:başar
# Surface:Kendinden, Stem:Ken
# Surface:korkan, Stem:kor
# Surface:öfke, Stem:öfk
# Surface:Web, Stem:Web
# Surface:sayfası, Stem:sayf
# Surface:dosyalarınızın, Stem:dosya
# Surface:uzantısı, Stem:uzantı
# Surface:olarak, Stem:o
# Surface:html, Stem:htm
# Surface:ya, Stem:ya
# Surface:da, Stem:da
# Surface:htm, Stem:ht
# Surface:kullanmanız, Stem:kullan
# Surface:herhangi, Stem:her
# Surface:bir, Stem:bi
# Surface:fark, Stem:far
# Surface:yaratmaz, Stem:yarat
# Surface:Sanatın, Stem:Sana
# Surface:evrensel, Stem:evren
# Surface:bir, Stem:bi
# Surface:değer, Stem:de
# Surface:olduğunu, Stem:ol
# Surface:vurgulayan, Stem:vurgula
# Surface:ressam, Stem:res
# Surface:Batı, Stem:Ba
# Surface:karşımızda, Stem:karş
# Surface:bir, Stem:bi
# Surface:gerçek, Stem:gerçe
# Surface:artık, Stem:ar
# Surface:sağ, Stem:sağ
# Surface:ve, Stem:ve
# Surface:solu, Stem:so
# Surface:bir, Stem:bi
# Surface:tarafa, Stem:taraf
# Surface:bırakıp, Stem:bırak
# Surface:kendi, Stem:ke
# Surface:sanatımızı, Stem:sanat
# Surface:üretmek, Stem:üre
# Surface:lazım, Stem:laz
# Surface:İran, Stem:İr
# Surface:Sineması, Stem:Sine
# Surface:bu, Stem:bu
# Surface:konuda, Stem:konu
# Surface:yapılabileceklere, Stem:yapılabilecek
# Surface:iyi, Stem:iy
# Surface:bir, Stem:bi
# Surface:örnek, Stem:örne
# Surface:diyor, Stem:di
# Surface:Freddie, Stem:Freddi
# Surface:Mercury, Stem:Mercur
# Surface:ölümünden, Stem:ölüm
# Surface:birkaç, Stem:birkaç
# Surface:yıl, Stem:yı
# Surface:sonra, Stem:son
# Surface:grubu, Stem:gru
# Surface:Queen, Stem:Que
# Surface:ile, Stem:il
# Surface:yeniden, Stem:yeni
# Surface:biraraya, Stem:birara
# Surface:geldi, Stem:gel
# Surface:Başka, Stem:Başk
# Surface:hareketlerin, Stem:hareket
# Surface:çalışmaları, Stem:çalış
# Surface:da, Stem:da
# Surface:vardı, Stem:va
# Surface:mahallelerde, Stem:mahalle
# Surface:ve, Stem:ve
# Surface:bu, Stem:bu
# Surface:nedenle, Stem:neden
# Surface:düpedüz, Stem:düped
# Surface:siyasi, Stem:siya
# Surface:bir, Stem:bi
# Surface:rekabet, Stem:rekabe
# Surface:içindeydik, Stem:içindey
# Surface:Bir, Stem:Bi
# Surface:de, Stem:de
# Surface:şu, Stem:şu
# Surface:gerçek, Stem:gerçe
# Surface:var, Stem:va
# Surface:ki, Stem:ki
# Surface:çizgi, Stem:çiz
# Surface:karakterler, Stem:karakt
# Surface:sanal, Stem:san
# Surface:dünyaya, Stem:dünya
# Surface:aitler, Stem:ait
# Surface:Eğer, Stem:Eğ
# Surface:kuşkulandığınız, Stem:kuşkulan
# Surface:bir, Stem:bi
# Surface:şey, Stem:şe
# Surface:varsa, Stem:va
# Surface:açığa, Stem:açı
# Surface:çıkması, Stem:çık
# Surface:çok, Stem:ço
# Surface:büyük, Stem:büyü
# Surface:ihtimaldir, Stem:ihtimal
# Surface:Hiçbir, Stem:Hiç
# Surface:yapısı, Stem:yapı
# Surface:hiçbir, Stem:hiç
# Surface:alanı, Stem:al
# Surface:yok, Stem:yo
# Surface:mu, Stem:mu
# Surface:çok, Stem:ço
# Surface:sevdiğiniz, Stem:sev
# Surface:Millet, Stem:Mille
# Surface:cahil, Stem:cah
# Surface:sanır, Stem:sa
# Surface:Geçmişimiz, Stem:Geçmiş
# Surface:ve, Stem:ve
# Surface:geleceğimizle, Stem:gelece
# Surface:bir, Stem:bi
# Surface:kazı, Stem:ka
# Surface:yerine, Stem:ye
# Surface:çevirmek, Stem:çev
# Surface:hayatımızı, Stem:hayat
# Surface:Hele, Stem:He
# Surface:bağımsızlık, Stem:bağım
# Surface:Nazmiye, Stem:Nazm
# Surface:hanım, Stem:han
# Surface:de, Stem:de
# Surface:diyor, Stem:di
# Surface:ben, Stem:be
# Surface:olmaz, Stem:ol
# Surface:diyorum, Stem:di
# Surface:Şaşkınlığımızı, Stem:Şaşkınlı
# Surface:henüz, Stem:he
# Surface:üzerimizden, Stem:üzer
# Surface:atamadan, Stem:at
# Surface:Japonların, Stem:Japo
# Surface:soruları, Stem:soru
# Surface:birbirini, Stem:birbi
# Surface:kovaladı, Stem:kova
# Surface:Çocuk, Stem:Çoc
# Surface:İlya, Stem:İl
# Surface:buluşuyor, Stem:buluş
# Surface:doğru, Stem:doğr
# Surface:uzanan, Stem:uza
# Surface:bir, Stem:bi
# Surface:yolculuğun, Stem:yolcu
# Surface:resmini, Stem:res
# Surface:çiziyor, Stem:çiz
# Surface:şiirini, Stem:şii
# Surface:yazıyor, Stem:yaz
# Surface:Neden, Stem:Ne
# Surface:terlik, Stem:ter
# Surface:Düelloyu, Stem:Düello
# Surface:T, Stem:T
# Surface:Mac, Stem:Ma
# Surface:kazandı, Stem:kaza
# Surface:Teyemmüm, Stem:Teyemm
# Surface:alıp, Stem:al
# Surface:avucunun, Stem:av
# Surface:içinde, Stem:iç
# Surface:küçük, Stem:küçü
# Surface:bir, Stem:bi
# Surface:tutarak, Stem:tu
# Surface:girdi, Stem:gi
# Surface:ameliyata, Stem:ameliya
